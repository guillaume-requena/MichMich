# %% [markdown]
# # Import and functions

# %%
import pandas as pd
import numpy as np
import requests
from urllib.parse import urlencode, urlparse , parse_qsl
import matplotlib.pyplot as plt

# %%
api_key = 'AIzaSyCEUIo5QkTQbHL8eBolEF6C4i0fSsnarFk'

# %%
def extract_lat_lng(address_or_postalcode, data_type = 'json'):
    '''
    extracts the lat and the lng from an adress
    '''
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {'address' : address_or_postalcode , "key" : api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200,299):
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except :
        pass
    return [latlng.get('lat'),latlng.get('lng')]

# %%
#Test 
#extract_lat_lng('24 boulevard du général Leclerc, Neuilly-sur-Seine, France')

# %%
def nearbysearch(lat, lng, radius, what = 'Bar'):
    '''
    returns the places corresponding to arg 'what' in a region of radius meters arround the point (lat,lng)
    '''
    places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params_2 = {
        "key" : api_key, 
        "location" : f"{lat},{lng}",
        "radius" : radius,
        "keyword" : what
    }
    params_2_encoded = urlencode(params_2)
    places_url = f"{places_endpoint_2}?{params_2_encoded}"
    r2 = requests.get(places_url)
    return r2.json()

# %%
#Test 
#nearbysearch(48.8890408,2.2596179,100)

# %%
def centre_gravite(points,coef_sum=[]):
    '''
    returns the centre de gravite of the points 
    '''
    points = np.array(points)
    if len(coef_sum)==0:
        coef_sum=np.array([1/len(points)]*len(points))
    x = np.array(points[:,0]*coef_sum).sum()
    y = np.array(points[:,1]*coef_sum).sum()
    return [x,y]

# %%
# #Test 

# points = [[2,3],[3,5],[0,6]]
# centre_gravite(points)

# %%
def get_time_and_distance_between_two_points(pt1,pt2,mode='transit'):
    '''
    returns the time in seconds between pt1 and pt2 according to the transport mode 'mode'
    mode can be : 
                    - driving 
                    - walking 
                    - bicycling 
                    - transit 
    '''
    lat1, lng1 = pt1[0],pt1[1]
    lat2, lng2 = pt2[0],pt2[1]
    detail_base_endpoint = 'https://maps.googleapis.com/maps/api/directions/json'
    detail_params = {
        "origin": str(lat1)+','+str(lng1),
        "destination" : str(lat2)+','+str(lng2),
        "key": api_key,
        "transit_mode" : "rail",
        "mode":mode
    }
    detail_params_encoded = urlencode(detail_params)
    detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"
    r = requests.get(detail_url)
    rep = r.json()
    duration = rep['routes'][0]['legs'][0]['duration']['value']
    distance = rep['routes'][0]['legs'][0]['distance']['value']
    return duration,distance

# %%
def normalize(vect):
    vect = np.array(vect)
    return vect/vect.sum()

# %%
# def change_center(old_center,points,weights):
#     weights = np.array(weights)
#     weights[(weights!=weights.max())&(weights!=weights.min())]=0
#     weights = normalize(weights)
    
#     x_new_center = old_center[0]+((points[:,0]-old_center[0])*weights).sum()
#     y_new_center = old_center[1]+((points[:,1]-old_center[1])*weights).sum()
#     return [x_new_center,y_new_center]

# %%
def main():
    n = int(input("Vous etes combien ? "))
    activity = input("Où voulez vous vous retrouvez? ")
    print("Moyen de transport disponibles: 'transit', 'walking', 'driving', 'cycling'")
    adresses = []
    transports = []
    for i in range(1,n+1):
        adresses.append(input(f"Entrez l'adresse n°{str(i)} : "))
        transports.append(input(f"Entrez votre moyen de transport n°{str(i)} : "))
    print('')
    print('**************************')
    print("Chargement des résultats")
    print('**************************')
    return mich_mich(adresses, modes_transport=transports, what = activity)

# %% [markdown]
# 24 boulevard du général Leclerc, Neuilly
#
# Place Monge, Paris
#
# Cité universitaire, Paris
#
# 19 Avenue Auguste Renoir, Marly-le-roi

# %%
r = main()
# Out:
# Vous etes combien ? 2
# Où voulez vous vous retrouvez? Bar
# Moyen de transport disponibles: 'transit', 'walking', 'driving', 'cycling'
# Entrez l'adresse n°1 : 19 Avenue Auguste Renoir, Marly-le-roi
# Entrez votre moyen de transport n°1 : driving
# Entrez l'adresse n°2 : 24 boulevard du général Leclerc, Neuilly
# Entrez votre moyen de transport n°2 : driving
#
# **************************
# Chargement des résultats
# **************************
# [1233  954]

# %%
r
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcnaJv2rpgLtJrT8CgTe7pTolZfbpv77C-OB5OWaUrw23r-up0C2WObSZUY1W4dqJ6Sba5xlO5vZzcXARNndTjBvotzNPH99iAjpSupERBe5HLYD5vnv2kqMIimoRtXQ2PcSiVk8trgOdL0Ulht-WdE95RFhWKtaYkdfzEgqcWe87u9N5YMpLYEUxi64b1VyTYqZCXulp0MTP9yVDK1Robea3FjkONBSE1o_F5-fxyKWbFkQGjn3MJE8S5sGrhA9NZtADmqOMumWczBHfkRkRLJAXKcBaQWp2nieoNhnLHOIXEu7v6d-8qc2Bg7WTZHhhmLaMgl_Nq4cooXqMFDDsMQ0r9qX80pJY1FgcavLx7ShzyxuW1kld01c3Dk8tkqiCBh1mVOQd7VBWXqQo-FBQcWIDpmy5n5SJC9DwezBVZRqj6rSEg',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.887407, 'lng': 2.1729023},
#     'viewport': {'northeast': {'lat': 48.88880877989271,
#       'lng': 2.174327729892722},
#      'southwest': {'lat': 48.88610912010727, 'lng': 2.171628070107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Train Pub',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110947617185943863098">David</a>'],
#      'photo_reference': 'CmRaAAAAs5WUmiX7Y1PEt6v_oQ9vKTUrKDQLMr5CKHxI50qAslAQm4P047sqonTduIICOKdkUWbcfR009820XwNkt0FpL8NeWymheaG8fCV3yYSFGdFgPa2hWP4cPJbVgf4CS_EKEhCzyZtFLNV5hVZr481LLRy5GhS3BWn6xSTV64zgjPwxrSKv3ShdIw',
#      'width': 3968}],
#    'place_id': 'ChIJPexH021j5kcR4TSxhjpuVHo',
#    'plus_code': {'compound_code': 'V5PF+X5 Rueil-Malmaison',
#     'global_code': '8FW4V5PF+X5'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJPexH021j5kcR4TSxhjpuVHo',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'meal_takeaway',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 533,
#    'vicinity': '8 Rue Pereire, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8753709, 'lng': 2.1810948},
#     'viewport': {'northeast': {'lat': 48.87671242989272,
#       'lng': 2.182392879892722},
#      'southwest': {'lat': 48.87401277010728, 'lng': 2.179693220107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Tiercé Bar',
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104021618922863644710">Jérome Laurence</a>'],
#      'photo_reference': 'CmRaAAAA7GhhgA7mgOro4qcpbSjzhlkLxCpnol4ieHTB8K_-QLlCdWzsdyXyp4eOp3DISFhZfQ8081LCa69WpqDPhmq1yECdr-SqyZp2WMUfF11h61rBm_cQgMBCyaX1IdpbKGGwEhDF_0dQuD-NoRghxAyRnCLBGhSEwWBVJ6ndf42jeyvV5dIwmEtcpw',
#      'width': 4608}],
#    'place_id': 'ChIJ-5KOZVxj5kcRmIebyLeUk1I',
#    'plus_code': {'compound_code': 'V5GJ+4C Rueil-Malmaison',
#     'global_code': '8FW4V5GJ+4C'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJ-5KOZVxj5kcRmIebyLeUk1I',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 37,
#    'vicinity': 'Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8794512, 'lng': 2.1836174},
#     'viewport': {'northeast': {'lat': 48.88083137989273,
#       'lng': 2.184948229892722},
#      'southwest': {'lat': 48.87813172010728, 'lng': 2.182248570107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': "Bar L'entr' Acte Brasserie",
#    'place_id': 'ChIJ67UWAF5j5kcRzuYhJVu-MJ0',
#    'plus_code': {'compound_code': 'V5HM+QC Rueil-Malmaison',
#     'global_code': '8FW4V5HM+QC'},
#    'rating': 0,
#    'reference': 'ChIJ67UWAF5j5kcRzuYhJVu-MJ0',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.88812919999999, 'lng': 2.1681278},
#     'viewport': {'northeast': {'lat': 48.88958032989272,
#       'lng': 2.169644379892722},
#      'southwest': {'lat': 48.88688067010728, 'lng': 2.166944720107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Gourmet Bar',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ1_d4OW1j5kcRaGHvpCvdZko',
#    'plus_code': {'compound_code': 'V5Q9+77 Rueil-Malmaison',
#     'global_code': '8FW4V5Q9+77'},
#    'rating': 3.8,
#    'reference': 'ChIJ1_d4OW1j5kcRaGHvpCvdZko',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': '21 Avenue Edouard Belin, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8794242, 'lng': 2.1836728},
#     'viewport': {'northeast': {'lat': 48.88076572989272,
#       'lng': 2.185032929892722},
#      'southwest': {'lat': 48.87806607010728, 'lng': 2.182333270107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': "Bar L'Entr'Acte",
#    'opening_hours': {},
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115339026531353655932">Patrick Pandolfi</a>'],
#      'photo_reference': 'CmRaAAAAzAj4Xxl9VaEHImB_zc7x1uMstBXlWJsHi942etNtPE6rhPNCCEGGEMRL9wEeCB0HuHNI_RPQXnOYEzh_Iy5G-Wc5-tqOUuK85EbEJGhu2l_UkEFwlOFLAnIrHQPyhuyOEhBuCeQoC48DRS1oDskI8CSnGhSzZZrrb4pdSGRTkmffL7HKozNKLw',
#      'width': 3264}],
#    'place_id': 'ChIJ4ZZIAF5j5kcRZ8HAJQ5Z2pc',
#    'plus_code': {'compound_code': 'V5HM+QF Rueil-Malmaison',
#     'global_code': '8FW4V5HM+QF'},
#    'price_level': 1,
#    'rating': 4.3,
#    'reference': 'ChIJ4ZZIAF5j5kcRZ8HAJQ5Z2pc',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': 'Rue du Dr Zamenhof, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8773759, 'lng': 2.1806038},
#     'viewport': {'northeast': {'lat': 48.87868957989272,
#       'lng': 2.181902529892722},
#      'southwest': {'lat': 48.87598992010728, 'lng': 2.179202870107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Au Verre Siffle',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101735463197118688332">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA0CUCJ_kwoT1BIxjDoxXGIhOp2LcIMV20mPgNLp-MzGDHRSYQpvIqMht6iK3huJvGMdBT1lTU5XUvgjiFFk-ww2rB0ITZv1-bvDwAmBz4CescRTRo2p7xac0fJpfq5PlKEhDHvmpNS9-qugxHzkcuvKCIGhTxxpaQH-CeMQYE4ZHna6-ADRccfw',
#      'width': 4032}],
#    'place_id': 'ChIJ38f4qV1j5kcR8MQYp2-nUQg',
#    'plus_code': {'compound_code': 'V5GJ+X6 Rueil-Malmaison',
#     'global_code': '8FW4V5GJ+X6'},
#    'rating': 4.1,
#    'reference': 'ChIJ38f4qV1j5kcR8MQYp2-nUQg',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 86,
#    'vicinity': "1 Passage d'Arcole, Rueil-Malmaison"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.886603, 'lng': 2.17043},
#     'viewport': {'northeast': {'lat': 48.88798362989272,
#       'lng': 2.171834329892723},
#      'southwest': {'lat': 48.88528397010727, 'lng': 2.169134670107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Napoléon',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100355534227752391633">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAM8r8XIWK3RWbZtK72ORevSL58iAiEUVhhZ3ZgfJnd_zZokyWFY8ZXi9wZQDkjN459BBmIufE7VxJSxZ4w2c18-is-_hBoYfB_UUhoy7f5E76j_U-hUlxZdrvldRaWiw_EhB4_LRUYZ60sb2yIXABs5GwGhT4fZGE2z4OYiCrrPa3JczzQWLKFg',
#      'width': 3096}],
#    'place_id': 'ChIJGcIWV2xj5kcRe-u2YeMaYJw',
#    'plus_code': {'compound_code': 'V5PC+J5 Rueil-Malmaison',
#     'global_code': '8FW4V5PC+J5'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJGcIWV2xj5kcRe-u2YeMaYJw',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 194,
#    'vicinity': '115 Avenue Albert 1er, Rueil-Malmaison'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8772543, 'lng': 2.1805295},
#     'viewport': {'northeast': {'lat': 48.87863247989272,
#       'lng': 2.181836679892722},
#      'southwest': {'lat': 48.87593282010727, 'lng': 2.179137020107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Café Leffe Rueil-Malmaison',
#    'permanently_closed': True,
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106567375373942177227">Paolo Zangrandi</a>'],
#      'photo_reference': 'CmRaAAAAzSKpTcg8ZOSPCWIDgrcC9umoAO7pnEmid-BoEg1rLVGnKrs3S22Go3CbH9Rn4rBEShZYfVaqT7pnVnZCqGXpdnvdB4optCjlkwSC3PjChkATnZnIxzv2XOKFlNogboVmEhCXl4tp7vnqkIYjr6c529vpGhSQCvwQJsA_AQVljjDeAUDoJ7GT-g',
#      'width': 4032}],
#    'place_id': 'ChIJ5yjXql1j5kcRDV8SJz800Xg',
#    'plus_code': {'compound_code': 'V5GJ+W6 Rueil-Malmaison',
#     'global_code': '8FW4V5GJ+W6'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJ5yjXql1j5kcRDV8SJz800Xg',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1063,
#    'vicinity': "2 Passage d'Arcole, Rueil-Malmaison"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8845824, 'lng': 2.1788111},
#     'viewport': {'northeast': {'lat': 48.88593192989273,
#       'lng': 2.180161429892722},
#      'southwest': {'lat': 48.88323227010729, 'lng': 2.177461770107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Martignon Chez Ricardo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117782295252551902664">Sonia De Almeida</a>'],
#      'photo_reference': 'CmRaAAAADoRhMk0DpgwmnYHg-Rd9-5OrpRAgQx_SVrgF2mM1fAvhof3_gywYKz1ps-IPI8uZscsNFW-naA5Jf__If4H8mNAMLwdmGHHYXoyaHDf4kpJ-evVp2WR65rO_yicfx7fnEhDfaxOuinCH3JKfbuxCYvvOGhRNGjsT_Klguaf9Kc45HRpw0ihNtw',
#      'width': 4032}],
#    'place_id': 'ChIJ7z3lBmZj5kcR5c4wdaun-rE',
#    'plus_code': {'compound_code': 'V5MH+RG Rueil-Malmaison',
#     'global_code': '8FW4V5MH+RG'},
#    'rating': 4.4,
#    'reference': 'ChIJ7z3lBmZj5kcR5c4wdaun-rE',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': '6 Rue Martignon, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.889075, 'lng': 2.1680399},
#     'viewport': {'northeast': {'lat': 48.89041612989272,
#       'lng': 2.169296279892722},
#      'southwest': {'lat': 48.88771647010728, 'lng': 2.166596620107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Aux Arcades',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108794953678556069378">Jérôme M</a>'],
#      'photo_reference': 'CmRaAAAAvN8BvMV6D4_Gnh0K64FjFpN9df_IxyEmMGjcr80UplVFER7jImBk7aX-XsKSz6vSTNYjRfp-w2e3M7LFNNksD3H_OUyt5-87JBLQsbVs4SXwOJVhIIFafXlwoyV8mn0XEhCt5YMZpieMFwkYhoVv0LSmGhRHkDo3KHnBhoacyPtEO3Bm514TZg',
#      'width': 1920}],
#    'place_id': 'ChIJN8RvOG1j5kcRBSPykW-s3JI',
#    'plus_code': {'compound_code': 'V5Q9+J6 Rueil-Malmaison',
#     'global_code': '8FW4V5Q9+J6'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJN8RvOG1j5kcRBSPykW-s3JI',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 245,
#    'vicinity': "4 Place de l'Europe, Rueil-Malmaison"},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8773743, 'lng': 2.1791771},
#     'viewport': {'northeast': {'lat': 48.87874227989273,
#       'lng': 2.180566679892722},
#      'southwest': {'lat': 48.87604262010728, 'lng': 2.177867020107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': "Brasserie l'Adresse",
#    'permanently_closed': True,
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106567375373942177227">Paolo Zangrandi</a>'],
#      'photo_reference': 'CmRaAAAAiaD0p0Vc4fUkdda9TR3aSilcmbTPMIuEhOsCKUv79_Ad_9noEsQ6ROyyuy4andSIbLwYjKv0ObS3Qt_J2sbXi36gR2BLKBRFUyFrN4J692DLASqzy3UsmCL1FSaCVvLrEhDGZeh0CtuLlj536gGYJGTcGhRPR0b1ibE_idpoimBaow6phDChgA',
#      'width': 4032}],
#    'place_id': 'ChIJr3KYWFxj5kcRL0F9NHYu0KQ',
#    'plus_code': {'compound_code': 'V5GH+WM Rueil-Malmaison',
#     'global_code': '8FW4V5GH+WM'},
#    'price_level': 2,
#    'rating': 3.4,
#    'reference': 'ChIJr3KYWFxj5kcRL0F9NHYu0KQ',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 426,
#    'vicinity': '2 Rue Hervet, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8792646, 'lng': 2.1847367},
#     'viewport': {'northeast': {'lat': 48.88060932989272,
#       'lng': 2.186095529892722},
#      'southwest': {'lat': 48.87790967010728, 'lng': 2.183395870107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Narval',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101285673440313126845">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAO-hufb4LeJENeosaXpV8H5NBrhPPDtywI0FsfzFQXU8IkqTa7xHAjV1HUFwkA78RgQlTBMzPndz26gALCPiVtlgMXM4V6GVR7o9JPthIUtLr2YjUznL9x6tVYg04hkEOEhAoASVF5E1QK5Uu5Ixhzr-LGhSewsniAqNFDF4NNm3PQ5omunfGjQ',
#      'width': 4032}],
#    'place_id': 'ChIJrTmEH15j5kcRyfylSujQ9EY',
#    'plus_code': {'compound_code': 'V5HM+PV Rueil-Malmaison',
#     'global_code': '8FW4V5HM+PV'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJrTmEH15j5kcRyfylSujQ9EY',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': '2 Rue du Gué, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8781071, 'lng': 2.1787261},
#     'viewport': {'northeast': {'lat': 48.87944082989272,
#       'lng': 2.180049629892723},
#      'southwest': {'lat': 48.87674117010728, 'lng': 2.177349970107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'MAMATO - Cave - Epicerie - Restaurant - Bar à vins',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104825501961558597258">Mailis le Guillou</a>'],
#      'photo_reference': 'CmRaAAAA2RUVz-ExuUIWGelTVC60aGuRRxmYRbk63dG6eC6P-o3ChWZ2M7yIyFo8iBk80E5ZhE9GfCzMmdWaJZLyOsoeFfIJr5wOLayt4hi1Yqp7SL1mCOisnFPyfZbGt_M67NRgEhCMzat2Lpgq9gL0NgFHdX8yGhQqIT_HoHOhckjd0B-55R0i_owI5g',
#      'width': 3024}],
#    'place_id': 'ChIJhz7TZV9j5kcRxCvi4W5DyQU',
#    'plus_code': {'compound_code': 'V5HH+6F Rueil-Malmaison',
#     'global_code': '8FW4V5HH+6F'},
#    'rating': 4.7,
#    'reference': 'ChIJhz7TZV9j5kcRxCvi4W5DyQU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'grocery_or_supermarket',
#     'bar',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 18,
#    'vicinity': '9 Place Jean Jaurès, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.879964, 'lng': 2.181268},
#     'viewport': {'northeast': {'lat': 48.88135492989272,
#       'lng': 2.182582979892722},
#      'southwest': {'lat': 48.87865527010727, 'lng': 2.179883320107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "L'Avenue",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108794953678556069378">Jérôme M</a>'],
#      'photo_reference': 'CmRaAAAAszfD8aVtmRZJpVtwxHrxMEEZK0pLASYx_GwLWUBnzERQcExUtn4zKSy0eux702g5mz9R4BMZ_wLxcxw04KLzAUTaZ4Rc7ahNsj_JLvBMBjOVKeyn32DdtGYOOOU7yY_HEhAxQATZb3M0RZ5jp5QtRImXGhTRAt4DMbR0sULiouM2H_n9BPs3Zw',
#      'width': 3036}],
#    'place_id': 'ChIJp-zKe2dj5kcRGW2S2JhQV0U',
#    'plus_code': {'compound_code': 'V5HJ+XG Rueil-Malmaison',
#     'global_code': '8FW4V5HJ+XG'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJp-zKe2dj5kcRGW2S2JhQV0U',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 619,
#    'vicinity': '95 Avenue Paul Doumer, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8875414, 'lng': 2.1734289},
#     'viewport': {'northeast': {'lat': 48.88885762989272,
#       'lng': 2.174727029892722},
#      'southwest': {'lat': 48.88615797010728, 'lng': 2.172027370107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'name': 'Café Pereire',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109781354690974163713">Erwan Le Coupanec</a>'],
#      'photo_reference': 'CmRaAAAAEZMDSkEVq5NTFA0YJIlfRMuY3BEoc2Hu8wDCHsVzQLtrkbnqeXigwLRfGLvrKFVyaE43mH9hxJwi9gBjc-Li6RN_jIYFzSuSFTqTGb9mqo341T757KBAD4nQCwC9Vy9UEhD6EZLq9z3HE0UMUit5u0h1GhRbyxCcFZ3skht71Np7hcljKtnlUQ',
#      'width': 3840}],
#    'place_id': 'ChIJIytOfG5j5kcR6PY4d8Iw6AY',
#    'plus_code': {'compound_code': 'V5QF+29 Rueil-Malmaison',
#     'global_code': '8FW4V5QF+29'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJIytOfG5j5kcR6PY4d8Iw6AY',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 183,
#    'vicinity': '74 Avenue Victor Hugo, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8760562, 'lng': 2.1808995},
#     'viewport': {'northeast': {'lat': 48.87746607989272,
#       'lng': 2.182198779892722},
#      'southwest': {'lat': 48.87476642010728, 'lng': 2.179499120107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Le Beauharnais',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2472,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101915789701582117196">Julien Sarboraria</a>'],
#      'photo_reference': 'CmRaAAAAJbrA_yRgQSuhzdWGEiE1KNkasnfFSTHxBiRjnRbQ-HOIKqUdg-VLmHOoxAq5Gr7vuDdgsfJB9t_1OfB0Ra_NYcXJK7ZhrCqR0YgX_5b5T45xGT1YWvco5AkkRJL5HjBDEhDqghPn3gVQ7U7He2CR0rfYGhT8TUdYwcVPgVAWkADbM6Un8h5bqQ',
#      'width': 3298}],
#    'place_id': 'ChIJZwIiXFxj5kcRJCAHVEaGfNA',
#    'plus_code': {'compound_code': 'V5GJ+C9 Rueil-Malmaison',
#     'global_code': '8FW4V5GJ+C9'},
#    'rating': 3.4,
#    'reference': 'ChIJZwIiXFxj5kcRJCAHVEaGfNA',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 160,
#    'vicinity': "29 Place de l'Église, Rueil-Malmaison"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.890152, 'lng': 2.1636798},
#     'viewport': {'northeast': {'lat': 48.89166827989272,
#       'lng': 2.165301279892722},
#      'southwest': {'lat': 48.88896862010728, 'lng': 2.162601620107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Les Rives de La Courtille',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3454,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118362072721028720296">Denis-John SAVEY</a>'],
#      'photo_reference': 'CmRaAAAABHpDJcU9W1SQq7FrqCSpoeS5jiEkzBN1i5yn6HF0szqHJO2j8brye7j0X_zh1hJndIW17ORJcY5eiWFiz5IXo0f_DI3-Wc7-ShEETcdvMBCJWm15dbUa0ImyJVfaE1pKEhB619dLKunnieFe96TGxz5nGhT2hHPhO7re10RxziNPglTob84qMw',
#      'width': 5182}],
#    'place_id': 'ChIJudoMWRFj5kcRN9u5QBIzELA',
#    'plus_code': {'compound_code': 'V5R7+3F Chatou',
#     'global_code': '8FW4V5R7+3F'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJudoMWRFj5kcRN9u5QBIzELA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 746,
#    'vicinity': '3 Rue du Bac, Chatou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8889873, 'lng': 2.1648594},
#     'viewport': {'northeast': {'lat': 48.89037652989272,
#       'lng': 2.166123129892723},
#      'southwest': {'lat': 48.88767687010727, 'lng': 2.163423470107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "L'Impressionniste",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3134,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111389590346641144724">Hugo Mercier</a>'],
#      'photo_reference': 'CmRaAAAAFqi_doh3GRO1r94q2kh7YPnT_XPyFVwK_3Fs72IEbiX03nmJUJHM2BGdTVo3r0H2ZL9VkLe8txhvqsTolMmg3Jd8YDFZCcJfJNu33UVmziwTuI1p4DSU3we-MLXOwyQ7EhCGQgjSOk6s_IxyVP0HOWwqGhQxt4XBVgMK5e969XGzlTpW7s0Mmg',
#      'width': 4752}],
#    'place_id': 'ChIJgyaViBJj5kcRaXnnOlyCe6U',
#    'plus_code': {'compound_code': 'V5Q7+HW Rueil-Malmaison',
#     'global_code': '8FW4V5Q7+HW'},
#    'rating': 3.8,
#    'reference': 'ChIJgyaViBJj5kcRaXnnOlyCe6U',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 54,
#    'vicinity': '13 Place des Impressionnistes, Rueil-Malmaison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8737874, 'lng': 2.1818766},
#     'viewport': {'northeast': {'lat': 48.87514742989272,
#       'lng': 2.183206579892722},
#      'southwest': {'lat': 48.87244777010727, 'lng': 2.180506920107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Richelieu',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104021618922863644710">Jérome Laurence</a>'],
#      'photo_reference': 'CmRaAAAAid5PzyL1nvIwpkublSkuuCr2Acqt4ZZqTNQROEw5yzW0voloqpkcGm8YvS3IL7jqezGQRuOrfEP-D3ysNIFvfwVgRGc0czPKemFJhMsWb3qFFQ8tjBF2IKltRAyBT5L6EhDfQVO4_zPwjMsAyRGFetvBGhR0gNKlf6d8DwBhuYwp7fsEXNkcyw',
#      'width': 4608}],
#    'place_id': 'ChIJrfHW7Ftj5kcR-0dCXXc_6-c',
#    'plus_code': {'compound_code': 'V5FJ+GQ Rueil-Malmaison',
#     'global_code': '8FW4V5FJ+GQ'},
#    'rating': 4.1,
#    'reference': 'ChIJrfHW7Ftj5kcR-0dCXXc_6-c',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 194,
#    'vicinity': '53 Rue Haute, Rueil-Malmaison'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.883045, 'lng': 2.1900012},
#     'viewport': {'northeast': {'lat': 48.88447122989272,
#       'lng': 2.191289679892722},
#      'southwest': {'lat': 48.88177157010728, 'lng': 2.188590020107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Hippopotamus',
#    'permanently_closed': True,
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118309351762123287720">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA-KoV179HMxgiJHPLGA0-LkJtlrkhU1ZCa78wZnI53ZmQH_Smvdzqkre7H-e-fIXwmDv6a3UTPacl6Qjq3ZFANFbU-1sIpULCyiNbmgigGkeI1vK5Byp0SqRgBX8qnjg1EhD507NHqkpkXWgnfKNxm8d_GhS7jxAdHzC2k7Yt2TCObL0VFEwgoQ',
#      'width': 1024}],
#    'place_id': 'ChIJwaBgIJ5k5kcRAiuEHdvspIA',
#    'plus_code': {'compound_code': 'V5MR+62 Rueil-Malmaison',
#     'global_code': '8FW4V5MR+62'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJwaBgIJ5k5kcRAiuEHdvspIA',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 808,
#    'vicinity': '33 Avenue Paul Doumer, Rueil-Malmaison'}],
#  'status': 'OK'}

# %%
def mich_mich(adresses, modes_transport, what = 'Bar',radius=1000):
    '''
    main function
    '''
    n = len(adresses)
    #Get the point in the middle 
    points = np.array([extract_lat_lng(adr) for adr in adresses])
    lat , lng = centre_gravite(points)
    center = [lat,lng]
    
    #Verifying that the new point is at an equal distance of everyone
    #If it's not the case, recalculates a new point 
    durations = []
    distances = []
    for i in range(n):
        p = points[i]
        transport_p = modes_transport[i]
        duration_p, distance_p = get_time_and_distance_between_two_points(p,center,transport_p)
        durations.append(duration_p)
        distances.append(distance_p)
    durations, distances = np.array(durations), np.array(distances)
    min_duration = durations.min()
    max_duration = durations.max()
    print(durations)
  
    #Get the results of the places at a distance < radius of the center calculated
    results =  nearbysearch(lat, lng, radius, what)
    return results
    n = len(results['results'])
    res = [ [results['results'][i]['name'],results['results'][i]['vicinity'], results['results'][i]['rating'] , results['results'][i]['user_ratings_total']]  for i in range(n)]
    res = np.array(res)
    res = np.flip(res[(res[:,2]).argsort()] , axis =0)
    print(res)
    return res

# %%
(np.array([0.34801871, 0.43637706, 0.21560423])*np.array([2.3521469,2.3089514,2.3385613])).sum()
# Out:
# 2.330368261877682

# %%
mich_mich(adresses, transports, what = 'Bar')
# Out:
# [[48.8427046  2.3521469]
#  [48.8278931  2.3089514]
#  [48.8198027  2.3385613]]
# coef_sum [0.33333333 0.33333333 0.33333333]
# points [[48.8427046  2.3521469]
#  [48.8278931  2.3089514]
#  [48.8198027  2.3385613]]
# [1354 1773  876]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.33824632 0.44291781 0.21883587]
# [48.825217678935445, 2.318743122310306]
# nouvelles durées [1708  757  392]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.59782989 0.26496325 0.13720686]
# [48.83842957866666, 2.3496109213333334]
# nouvelles durées [ 423 2913 1747]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.08321857 0.57308676 0.34369467]
# [48.829771176888485, 2.3144285272482015]
# nouvelles durées [1825  602  847]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.55742211 0.18387294 0.25870495]
# [48.83903071330861, 2.3414325650185415]
# nouvelles durées [ 945 2597  953]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.21023359 0.57775306 0.21201335]
# [48.831844784782604, 2.3204758911067196]
# nouvelles durées [1739  952 1061]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.46348614 0.25373134 0.28278252]
# [48.83746470850984, 2.3368655488294316]
# nouvelles durées [1284 2538  897]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.27209154 0.53782581 0.19008264]
# [48.82578041039301, 2.3166835922270743]
# nouvelles durées [1841  633  525]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.61387129 0.21107036 0.17505835]
# [48.83762281745562, 2.3491323437869824]
# nouvelles durées [ 473 2841 1755]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.09331229 0.56046558 0.34622213]
# [48.83000711312613, 2.315116599607725]
# nouvelles durées [1798  647  891]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.53896882 0.19394484 0.26708633]
# [48.83878515603272, 2.340716434355828]
# nouvelles durées [ 956 2503  859]
# 3926
# 100
# [['Café Léa' '5 Rue Claude Bernard, Paris' '4.4' '491']
#  ['Aux Marsouins' '50 Boulevard de Port-Royal, Paris' '4.6' '188']
#  ['Bar Le 1802' '22 Rue Pascal, Paris' '4.7' '73']
#  ['La belle mine' '58 Rue Claude Bernard, Paris' '4.7' '112']
#  ['Le Repaire' '20 Rue Censier, Paris' '4.1' '154']
#  ['Bar Tabac' '123 Rue Monge, Paris' '4.5' '8']
#  ['Bar On Fleek Mouffetard' '104 Rue Mouffetard, Paris' '4.6' '18']
#  ['Fischer Winner Bar' '4 Rue Michel Peter, Paris' '4.8' '5']
#  ['Bar À Bières Cocktails' 'Rue de la Glacière, Paris' '0' '0']]
# array([['Fischer Winner Bar', '4 Rue Michel Peter, Paris', '4.8', '5'],
#        ['La belle mine', '58 Rue Claude Bernard, Paris', '4.7', '112'],
#        ['Bar Le 1802', '22 Rue Pascal, Paris', '4.7', '73'],
#        ['Bar On Fleek Mouffetard', '104 Rue Mouffetard, Paris', '4.6',
#         '18'],
#        ['Aux Marsouins', '50 Boulevard de Port-Royal, Paris', '4.6',
#         '188'],
#        ['Bar Tabac', '123 Rue Monge, Paris', '4.5', '8'],
#        ['Café Léa', '5 Rue Claude Bernard, Paris', '4.4', '491'],
#        ['Le Repaire', '20 Rue Censier, Paris', '4.1', '154'],
#        ['Bar À Bières Cocktails', 'Rue de la Glacière, Paris', '0', '0']],
#       dtype='<U33')

# %% [markdown]
# 24 boulevard du général Leclerc, Neuilly
#
# Place Monge, Paris
#
# Cité universitaire, Paris
#
# 19 Avenue Auguste Renoir, Paris

# %%
n = int(input("Vous etes combien ? "))
where = input("Vous voulez aller où? ")
adresses = []
for i in range(n):
    adresses.append(input("Entrez l'adresse n°{} : ".format(str(i))))
# Out:
# Vous etes combien ? 3
# Vous voulez aller où? Bar
# Entrez l'adresse n°0 : Place Monge, Paris
# Entrez l'adresse n°1 : 19 Avenue Auguste Renoir, Paris
# Entrez l'adresse n°2 : Cité universitaire, Paris

# %%
adresses
# Out:
# ['Place Monge, Paris ',
#  '19 Avenue Auguste Renoir, Paris',
#  'Cité universitaire, Paris']

# %%
transports = ["transit","walking","transit"]

# %%
mich_mich(adresses, transports, what = 'Bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-88efb8917f38> in <module>
# ----> 1 mich_mich(adresses, transports, what = 'Bar')
#
# <ipython-input-35-8947efe01209> in mich_mich(adresses, modes_transport, what)
#      16         p = points[i]
#      17         transport_p = modes_transport[i]
# ---> 18         duration_p, distance_p = get_time_and_distance_between_two_points(p,center,transport_p)
#      19         durations.append(duration_p)
#      20         distances.append(distance_p)
#
# NameError: name 'get_time_and_distance_between_two_points' is not defined
