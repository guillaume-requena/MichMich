# %%
import requests
from urllib.parse import urlencode, urlparse, parse_qsl

# %%
GOOGLE_API_KEY = 'AIzaSyCEUIo5QkTQbHL8eBolEF6C4i0fSsnarFk'

# %%
class GoogleMapsClient(object):
    
    lat = None
    lng = None
    data_type = 'json'
    location_query = None
    api_key = None
    
    def __init__(self, api_key=None, address_or_postal_code=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        if api_key == None:
            raise Exception("API key is required")
        self.api_key = api_key
        self.location_query = address_or_postal_code
        if self.location_query != None:
            self.extract_lat_lng()
    
    def extract_lat_lng(self, location=None):
        loc_query = self.location_query
        if location != None:
            loc_query = location
        endpoint = f"https://maps.googleapis.com/maps/api/geocode/{self.data_type}"
        params = {"address": loc_query, "key": self.api_key}
        url_params = urlencode(params)
        url = f"{endpoint}?{url_params}"
        r = requests.get(url)
        if r.status_code not in range(200, 299): 
            return {}
        latlng = {}
        try:
            latlng = r.json()['results'][0]['geometry']['location']
        except:
            pass
        lat,lng = latlng.get("lat"), latlng.get("lng")
        self.lat = lat
        self.lng = lng
        return lat, lng
    
    def search(self, keyword="Mexican food", radius=5000, location=None):
        lat, lng = self.lat, self.lng
        if location != None:
            lat, lng = self.extract_lat_lng(location=location)
        endpoint = f"https://maps.googleapis.com/maps/api/place/nearbysearch/{self.data_type}"
        params = {
            "key": self.api_key,
            "location": f"{lat},{lng}",
            "radius": radius,
            "keyword": keyword
        }
        params_encoded = urlencode(params)
        places_url = f"{endpoint}?{params_encoded}"
        r = requests.get(places_url)
        # print(places_url, r.text)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def detail(self, place_id="ChIJlXOKcDC3j4ARzal-5j-p-FY", fields=["name", "rating", "formatted_phone_number", "formatted_address"]):
        detail_base_endpoint = f"https://maps.googleapis.com/maps/api/place/details/{self.data_type}"
        detail_params = {
            "place_id": f"{place_id}",
            "fields" : ",".join(fields),
            "key": self.api_key
        }
        detail_params_encoded = urlencode(detail_params)
        detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"
        r = requests.get(detail_url)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
client = GoogleMapsClient(api_key=GOOGLE_API_KEY, address_or_postal_code='92660')

# %%
print(client.lat, client.lng)
# Out:
# 33.6301328 -117.8721676

# %%
client.search("Tacos", radius=5000)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCGgEAAI_7O8RAJw87HOVlBtm9iOYjzYfaQUQeAPvYxArc5WIw0UAZjS65PNCrGopkgOp4TStbmOyCD3Ol-MT54keFi3nen1IqXM8xsgWAX_eq_Qpcd_Pj6ho3DjpOsBq5f4tUTw3ABNeUJ31a1R0Ly7cj2YdeoSM0gbr3_-qtLIsUYS8usBfP_5LSd591KWzLlXQA6YVfoEsMKxITbrM8WhMVRZKTr7DpSbxQUy23wgdptyhJcqNt0nUIPEUmEBnnxojbIeAUfrszLFzh7hvCvZY8ni4eXuSUIOrFCfI9aaFTlODVSI1VDx5wH1olNx90CX3VqyernC3MFv26SbdGpk_oo9CcEOAAW-2Ipwzwxxan1dMF4oHMz0c17AYwZXSO2iHWsBIQOsJjpIGqd0oin0bys6evaRoUy9SLTLbeTM4Nly7T8OAQZ9LADEw',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6622722, 'lng': -117.8970417},
#     'viewport': {'northeast': {'lat': 33.66358552989271,
#       'lng': -117.8956352701072},
#      'southwest': {'lat': 33.66088587010727, 'lng': -117.8983349298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taco Grill #2',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2136,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104003251157474534594">Christian #</a>'],
#      'photo_reference': 'CmRaAAAA-ywQZACUQI_n3m6fHVoqniZhhPzfZdSMEWYwHdSLLZ9p7iwcbMB108aEE0cv_hYbLVBuD0wzY0CFKzlSH1evj9x5r86BuOBExM3eJ6O1U70UuowJCSxy9xG8iEsGqfTnEhBNV4ac2Dx5PfypRD6aknaMGhQavXRpWIVkYTAViIYziR0e31R3tA',
#      'width': 3798}],
#    'place_id': 'ChIJ3dToNQrf3IARpZPIhyFGFOs',
#    'plus_code': {'compound_code': 'M463+W5 Costa Mesa, California, United States',
#     'global_code': '8554M463+W5'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJ3dToNQrf3IARpZPIhyFGFOs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 146,
#    'vicinity': '# D, 2590 Newport Blvd # D, Costa Mesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.62901300000001, 'lng': -117.90634},
#     'viewport': {'northeast': {'lat': 33.63029682989273,
#       'lng': -117.9050799201073},
#      'southwest': {'lat': 33.62759717010728, 'lng': -117.9077795798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Chronic Tacos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 965,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104941067424223322386">Chronic Tacos</a>'],
#      'photo_reference': 'CmRaAAAAezPB-R-dsAK1zsMxVCvPvvO1lYADpeT5W4A7Rzib1noAQfoqh7mIlTeYPw_aBSImgWw3rHYtAdG-ckxOnwUczSI3Y3stJTwsgDHjD-VV-JuOz0JMZkFreOnQ1JzrOmuuEhAFAo7AtOJhMpK8ujczbfYRGhTSMr3OyfdM_Q7OfsbhBioGbAfNMw',
#      'width': 1716}],
#    'place_id': 'ChIJna2mKO_f3IARB1ONadjAnUM',
#    'plus_code': {'compound_code': 'J3HV+JF Newport Beach, California, United States',
#     'global_code': '8554J3HV+JF'},
#    'price_level': 1,
#    'rating': 4.2,
#    'reference': 'ChIJna2mKO_f3IARB1ONadjAnUM',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 87,
#    'vicinity': '1120 Irvine Ave, Newport Beach'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6437171, 'lng': -117.9187395},
#     'viewport': {'northeast': {'lat': 33.64506582989272,
#       'lng': -117.9174700701073},
#      'southwest': {'lat': 33.64236617010728, 'lng': -117.9201697298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Tacos Cancun',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116581812012097206143">Jivesh Sabnani</a>'],
#      'photo_reference': 'CmRaAAAAxlHLkGVXdkNDNFADyjh5oe2anUiZweEkBpMJXh-Q-dkNFatT8yiz2IEt3PZ71sFJWyyGgFAl-2d0yV1YChybuHCGDESvYZhy34Lsme9Jg2oXLRUA9CZjuRWFZSzXuUrsEhA2aZH8_kZGF39Jovdo4slaGhTjeNlLhnk9nZcy2JXz0aZC1O3viw',
#      'width': 4032}],
#    'place_id': 'ChIJGagzTI_f3IAR7exqNSk85MQ',
#    'plus_code': {'compound_code': 'J3VJ+FG Costa Mesa, California, United States',
#     'global_code': '8554J3VJ+FG'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJGagzTI_f3IAR7exqNSk85MQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 152,
#    'vicinity': '1902 Harbor Blvd, Costa Mesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6637007, 'lng': -117.8259907},
#     'viewport': {'northeast': {'lat': 33.66511037989272,
#       'lng': -117.8247373201073},
#      'southwest': {'lat': 33.66241072010727, 'lng': -117.8274369798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Tacos & Co',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107948728342672257567">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAF2g_sBU_WCGE1ivOlcdVn_ONg3oN2XOJS7rzPjwDIIYSK16laXer3ZOmlEqGHiqSrMgSjKldpTx10t3WYp6h5XdPzUg7hsnFnd1qgWM6WC11f15STvw1Y5UQDEhm2nt1EhBeXhWainG3wZxbK3uqHkGiGhQqzj9lodlDVZP--mJNMBQ0vK6aXg',
#      'width': 3024}],
#    'place_id': 'ChIJ89HCL9nd3IARrSfPK-FVglE',
#    'plus_code': {'compound_code': 'M57F+FJ Irvine, California, United States',
#     'global_code': '8554M57F+FJ'},
#    'price_level': 1,
#    'rating': 3.7,
#    'reference': 'ChIJ89HCL9nd3IARrSfPK-FVglE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 197,
#    'vicinity': '18092 Culver Dr, Irvine'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.625949, 'lng': -117.848471},
#     'viewport': {'northeast': {'lat': 33.62745052989272,
#       'lng': -117.8472936201073},
#      'southwest': {'lat': 33.62475087010728, 'lng': -117.8499932798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taco Rosa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100704826023548960305">Nicole Ambrozich</a>'],
#      'photo_reference': 'CmRaAAAAgzEVj9E1uHarEplOhAJRm8I_oVNi2n0SsKmsTSgzqDUOIftapvPaNvEiOk_ZgYfLBj6gFuMZGYkAyhkN087-zkk07HT_LCtPLmudBRd80Oy9TWiJL414EtflG0UM7muWEhBkVZMmOuKxGSVpTkk1G7yKGhSm9ZsDXod_xvXxBiJpW1LphK9iwA',
#      'width': 5312}],
#    'place_id': 'ChIJ3_UcP6Hg3IARe8PGKDSewv4',
#    'plus_code': {'compound_code': 'J5G2+9J Newport Beach, California, United States',
#     'global_code': '8554J5G2+9J'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJ3_UcP6Hg3IARe8PGKDSewv4',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 168,
#    'vicinity': '2632 San Miguel Dr, Newport Beach'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6498359, 'lng': -117.8307965},
#     'viewport': {'northeast': {'lat': 33.65108637989272,
#       'lng': -117.8294290701073},
#      'southwest': {'lat': 33.64838672010728, 'lng': -117.8321287298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Del Taco',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114545650858000777838">Brian Yamagata</a>'],
#      'photo_reference': 'CmRaAAAAurmRU9W9f9az6jDC8y7tER4u2Gu5dilmyYT7NaSOSomu0beQSZoMtvO7WaWbg_wdUthZVIfFf0PJn6XfKN80VqBIMZ2Iw5B3H4US7vSA9cvgUoaZw9VEaanO8loaxr1CEhCGuMxiniw-TjBqHfQP9qg2GhQfy9Sh5Rj1WN2fXemhpXSyI2VVBQ',
#      'width': 1280}],
#    'place_id': 'ChIJCfEnZvfe3IAR-wUoHk2ewtg',
#    'plus_code': {'compound_code': 'J5X9+WM Irvine, California, United States',
#     'global_code': '8554J5X9+WM'},
#    'price_level': 1,
#    'rating': 3.9,
#    'reference': 'ChIJCfEnZvfe3IAR-wUoHk2ewtg',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 226,
#    'vicinity': '4547 Campus Dr, Irvine'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6509716, 'lng': -117.8409098},
#     'viewport': {'northeast': {'lat': 33.65219717989272,
#       'lng': -117.8396507201073},
#      'southwest': {'lat': 33.64949752010728, 'lng': -117.8423503798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taco Bell',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104175352663830499545">Taco Bell</a>'],
#      'photo_reference': 'CmRaAAAAwMVBkFODGVCUDyb752mxAB9ZMoqTZv1HBsuYUU3D9SVS0LSEDMySHSLTOmafsZPbzwQHtwK9Cu5BGPRrvTe69NRTJhWZtdpA-yH77k607xwdrjoaHk0epWWr9mIraCwyEhDWEWDobf3ODgUyyt38Cn6fGhR7-_jSscFxnr1DtB5sNI8esPE_Lg',
#      'width': 600}],
#    'place_id': 'ChIJBeDKDA3e3IARICnG5DZiO2g',
#    'plus_code': {'compound_code': 'M525+9J Irvine, California, United States',
#     'global_code': '8554M525+9J'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJBeDKDA3e3IARICnG5DZiO2g',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 388,
#    'vicinity': '4101 Campus Dr, Irvine'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.636503, 'lng': -117.922939},
#     'viewport': {'northeast': {'lat': 33.63793292989272,
#       'lng': -117.9214920701073},
#      'southwest': {'lat': 33.63523327010728, 'lng': -117.9241917298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Del Taco',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104506413693278439990">Jim Kuhlman</a>'],
#      'photo_reference': 'CmRaAAAASkurzpHQVJ-Or6n_HMruJSNY3It8stdWIp6_0awY7NGjaUmTJFDO4zClrnpPvXF_DKwA8slwGn_4nv_NIViGYjTEmK3DgxqexbWfepGL-Pb9L0L2lMOIDrzehxTC8xoVEhB1Mz-jhsgvMXftg-yPhTIlGhRFCrOBM3LdGaXZ7Co4MLWLmyfM2A',
#      'width': 1908}],
#    'place_id': 'ChIJL5aLT4rf3IARBiWOWo1ez2o',
#    'plus_code': {'compound_code': 'J3PG+JR Costa Mesa, California, United States',
#     'global_code': '8554J3PG+JR'},
#    'price_level': 1,
#    'rating': 3.9,
#    'reference': 'ChIJL5aLT4rf3IARBiWOWo1ez2o',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1249,
#    'vicinity': '1720 Superior Ave, Costa Mesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6612715, 'lng': -117.8748387},
#     'viewport': {'northeast': {'lat': 33.66264902989273,
#       'lng': -117.8734321701073},
#      'southwest': {'lat': 33.65994937010728, 'lng': -117.8761318298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Del Taco',
#    'opening_hours': {},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104442839397499258750">Chad MacDonald</a>'],
#      'photo_reference': 'CmRaAAAATboIbBDnViECML2atFFsoJZbAy2wPp2qv6meoqbiR9ucn64fEjw26SyV8JmCz5eVbuHivG0hFOl_MBop8hBCK3jS73Yj25o4-tYeQmDPLhAYc9EeZXUn9FB3GMkPnGRIEhDAFelnw2mbkuy8wJuOWR7BGhSiE-lgHMB4jdpaH_UpBvexg6MwCA',
#      'width': 1080}],
#    'place_id': 'ChIJH8oJ9VTe3IARr_er4hnnQNo',
#    'plus_code': {'compound_code': 'M46G+G3 Newport Beach, California, United States',
#     'global_code': '8554M46G+G3'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJH8oJ9VTe3IARr_er4hnnQNo',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 449,
#    'vicinity': '2112 SE Bristol St, Newport Beach'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6725736, 'lng': -117.846712},
#     'viewport': {'northeast': {'lat': 33.67395427989271,
#       'lng': -117.8452094201073},
#      'southwest': {'lat': 33.67125462010727, 'lng': -117.8479090798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "Wahoo's Fish Taco",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107663922997380339721">Robin Kelly</a>'],
#      'photo_reference': 'CmRaAAAAlv9LZkX0v_N-qydxyopuY5X373D5VX-0oMtBz6-5RgB_WrOf4zUL08BcQW8Wt3B9OfmCZWdRjXQefx2K1qJQt6Gb2EJmzMPljhSwK-Y1YScNbFxIJrRymkhnrqZ99A57EhAmwBXjTYp_Ke7hboP2vQmvGhTJBEXGXSEMF-ni6784Qtd3NLhZ2g',
#      'width': 2048}],
#    'place_id': 'ChIJueN272Le3IARLo4h-8obJg8',
#    'plus_code': {'compound_code': 'M5F3+28 Irvine, California, United States',
#     'global_code': '8554M5F3+28'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJueN272Le3IARLo4h-8obJg8',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 268,
#    'vicinity': '2967 Michelson Dr, Irvine'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6360926, 'lng': -117.9204358},
#     'viewport': {'northeast': {'lat': 33.63715347989272,
#       'lng': -117.9189600201073},
#      'southwest': {'lat': 33.63445382010728, 'lng': -117.9216596798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Baja Fish Tacos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105215255461629201350">Aaron Roberts Jr.</a>'],
#      'photo_reference': 'CmRaAAAAH5x1Fh5hSm2uBHeKyUE71pP1hzuay1OzcaxI_nx8mgPGQW4QqMLZiv8rba_66RN-KlQ5z_xmJOaDgb9XKKcPvkWMtwAGckBuR4QS4S8oEiwPGrnWA2E3kIjgwwkiQSNtEhBrvNJTmlbL0WHRF-jEelqVGhQzoy5ky33BmHVAmxjib9MpGKIj9g',
#      'width': 3024}],
#    'place_id': 'ChIJuXcNC4vf3IARWdOnkq2JiFs',
#    'plus_code': {'compound_code': 'J3PH+CR Costa Mesa, California, United States',
#     'global_code': '8554J3PH+CR'},
#    'price_level': 1,
#    'rating': 4.7,
#    'reference': 'ChIJuXcNC4vf3IARWdOnkq2JiFs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 326,
#    'vicinity': '171 E 17th St, Costa Mesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.643193, 'lng': -117.925256},
#     'viewport': {'northeast': {'lat': 33.64465737989272,
#       'lng': -117.9239796201072},
#      'southwest': {'lat': 33.64195772010728, 'lng': -117.9266792798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taco Mesa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115254260815728714694">Brian Hoard</a>'],
#      'photo_reference': 'CmRaAAAAmo3VcsaLJAvH4I2ECFYF1dT0-pDrVvsee7NuR_rhSMlGSuDJN2FjWw1PfzWVOcUc_M1KutEyJ2f7w-l6O8vEojZS0Me58n94YQAm02fjMchIpHDg1mfVLbW4VZDNTpPLEhDJAR_XTpAs6FcCO3cNYHwYGhS_LKRf6KPpTPM3-8bvAIiINwsS6Q',
#      'width': 1280}],
#    'place_id': 'ChIJYezFA3gg3YARXjNBPahA-xw',
#    'plus_code': {'compound_code': 'J3VF+7V Costa Mesa, California, United States',
#     'global_code': '8554J3VF+7V'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJYezFA3gg3YARXjNBPahA-xw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1317,
#    'vicinity': '647 W 19th St, Costa Mesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.616373, 'lng': -117.87465},
#     'viewport': {'northeast': {'lat': 33.61781677989272,
#       'lng': -117.8731963701073},
#      'southwest': {'lat': 33.61511712010728, 'lng': -117.8758960298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "Wahoo's Fish Taco",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102723251077111914625">Anthony Fazio</a>'],
#      'photo_reference': 'CmRaAAAAhvm_oWXlhqbnBhQDzqF4uF0kB0KRBF4HI1aPULhFWBgrTOwwbu3K3fA_Mn8w6V0VhHKQTFOcfM9bofK4uMfj_CnJrrvTZocGvDQp8_09EVtx0O-SLxXoOx0l9quh48Q-EhDcQf6IVlXiSWUVCu8zn3sMGhTyRF8Io5Q3c9mVtQjbnLuw8EW7sA',
#      'width': 3000}],
#    'place_id': 'ChIJ5X5B9ofg3IARf0JuwY8Tks8',
#    'plus_code': {'compound_code': 'J48G+G4 Newport Beach, California, United States',
#     'global_code': '8554J48G+G4'},
#    'price_level': 1,
#    'rating': 4.4,
#    'reference': 'ChIJ5X5B9ofg3IARf0JuwY8Tks8',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 176,
#    'vicinity': '401 Newport Center Dr, Newport Beach'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.594315, 'lng': -117.86866},
#     'viewport': {'northeast': {'lat': 33.59574492989272,
#       'lng': -117.8672698201073},
#      'southwest': {'lat': 33.59304527010728, 'lng': -117.8699694798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Chronic Tacos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 965,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110575603474676467834">Chronic Tacos</a>'],
#      'photo_reference': 'CmRaAAAASKUgj4ANzMeknQFTOEMwBCZokqbxbhUa6JsfAlSVfl-YylbeTfmYDKKpnSgb29OHVgAyo9-VxN6fX99o8xo7AXLmS45MSSPUyTJkj1ZvNSxWQGWQSZGGQQCaMuPUCdYtEhBXp0HrFI-RFNhQvrUi2y7fGhRaRqSz5bFGL-9bfx3CFnnYY5wajw',
#      'width': 1716}],
#    'place_id': 'ChIJbah4g_rg3IAREgYLrrvuink',
#    'plus_code': {'compound_code': 'H4VJ+PG Newport Beach, California, United States',
#     'global_code': '8554H4VJ+PG'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJbah4g_rg3IAREgYLrrvuink',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 323,
#    'vicinity': '3601 CA-1, Corona Del Mar'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6596858, 'lng': -117.8611467},
#     'viewport': {'northeast': {'lat': 33.66095587989272,
#       'lng': -117.8596910701073},
#      'southwest': {'lat': 33.65825622010728, 'lng': -117.8623907298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taco Bell',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112846803871862098403">Taco Bell</a>'],
#      'photo_reference': 'CmRaAAAAXzbdvW7EcdJc2ur1XvO38MigzUTjIn2V5mM3PtU7gbXzU1czXl02e3AGF9v7yrIZjyRZMbITZJveDjTlAk4AhI3DdQ1jXLndFnpfBKd7XzVacv1l9_69xU4yJO56_dBJEhDLdBy7f8RP_ta426A4KiDkGhRyPyZFSjOuh2EDOKkKljzNIbYAyQ',
#      'width': 600}],
#    'place_id': 'ChIJ76gFXVve3IARuQAPKqfhgj4',
#    'plus_code': {'compound_code': 'M45Q+VG Newport Beach, California, United States',
#     'global_code': '8554M45Q+VG'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJ76gFXVve3IARuQAPKqfhgj4',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 391,
#    'vicinity': '4101 Jamboree Rd, Newport Beach'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6565033, 'lng': -117.9197476},
#     'viewport': {'northeast': {'lat': 33.65784682989273,
#       'lng': -117.9183228201073},
#      'southwest': {'lat': 33.65514717010728, 'lng': -117.9210224798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taco Bell',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117864727789626605278">Taco Bell</a>'],
#      'photo_reference': 'CmRaAAAA6lzk1tZa2W84Q0ltXk_RhbF6OyWVhmVbWdgULN848xvw3PjWeE-1oTrrvnzRM9qyfljA6Jp02ooR3qURjA5k--B6iGF-iwkc_jZjiOvZX3H5F-E_cBDocQsOHqSJ2Nt0EhDcMs_scYzi3H7U0lNlseiqGhTGvvtaKqK_8cv-6Mv5jW7Z8cORJg',
#      'width': 600}],
#    'place_id': 'ChIJ2y6AMn_f3IARE2jIhuT6mR4',
#    'plus_code': {'compound_code': 'M34J+J4 Costa Mesa, California, United States',
#     'global_code': '8554M34J+J4'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'ChIJ2y6AMn_f3IARE2jIhuT6mR4',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 589,
#    'vicinity': '2259 Harbor Blvd, Costa Mesa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6012189, 'lng': -117.8999553},
#     'viewport': {'northeast': {'lat': 33.60255522989272,
#       'lng': -117.8985594701072},
#      'southwest': {'lat': 33.59985557010728, 'lng': -117.9012591298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Tacos Cancun',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3638,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100135666244669193450">Rich Bennett</a>'],
#      'photo_reference': 'CmRaAAAArtTMOnyBWDgENIp8qZTENOJg6Hupz_jPe35Xk0cASnVipPjYJalVGffo_H6YA1kY1At1OlzSry9pq5aS7pUQdrFIhABgt6u23Utp14IQHL1s1KgJx9uiTlb91hXL5OljEhDaJ5FbPDaIYi5cOiUogjaBGhSaAE8plQgufE5jyQ4hPHA9ccwmIg',
#      'width': 1960}],
#    'place_id': 'ChIJr376GxDg3IAR6A4H5u1y_mE',
#    'plus_code': {'compound_code': 'J422+F2 Newport Beach, California, United States',
#     'global_code': '8554J422+F2'},
#    'rating': 4.6,
#    'reference': 'ChIJr376GxDg3IAR6A4H5u1y_mE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 50,
#    'vicinity': '707 E Oceanfront, Newport Beach'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.59851100000001, 'lng': -117.871504},
#     'viewport': {'northeast': {'lat': 33.59983017989273,
#       'lng': -117.8702871701073},
#      'southwest': {'lat': 33.59713052010728, 'lng': -117.8729868298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Baja Fresh',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3744,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108134840731659967576">Baja Fresh Mexican Grill</a>'],
#      'photo_reference': 'CmRaAAAAEiDA1jM2nkOhX46RdpT2-G-So3hNZpLH14vHB3Jn0-m5MP318StDMNbH8CeYFNcl0SoIVtSJepxS19OP_NA1wBI5wv1ispbe6NHkKtd8L8kfw5yd8dpiAmKGVTiYCg23EhDbwMFcvMbgO34TfNqo-RYbGhSDvoSWAD2jpg_7oaYGZNvT9FvAwA',
#      'width': 5616}],
#    'place_id': 'ChIJPdZzT_Hg3IARZ6GKzgpHMDw',
#    'plus_code': {'compound_code': 'H4XH+C9 Newport Beach, California, United States',
#     'global_code': '8554H4XH+C9'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJPdZzT_Hg3IARZ6GKzgpHMDw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 222,
#    'vicinity': '3050 East Coast Hwy, Corona Del Mar'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6492187, 'lng': -117.8315921},
#     'viewport': {'northeast': {'lat': 33.65056907989272,
#       'lng': -117.8302444201073},
#      'southwest': {'lat': 33.64786942010728, 'lng': -117.8329440798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Taquiero Taco Patio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 750,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107299921007060495149">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA3ew96Z7YqebnhiSrIdumyTUYHdfoAbsJ-slYXNN7dm1z3k9e76eBpvYhen_8zTyGh6Ay52ypeBnGgzUckg967Wf86pGbMP3yHeDW8se8JNKwwY6XYLBQ6QQAZ5uzl3lIEhCsdyj9wcCjqah8lxkiWwRUGhTR5xxIXhcmkwxr-6M3zkssof0zJQ',
#      'width': 1200}],
#    'place_id': 'ChIJQ4VJg3Hf3IARUwlv2UsFPvI',
#    'plus_code': {'compound_code': 'J5X9+M9 Irvine, California, United States',
#     'global_code': '8554J5X9+M9'},
#    'rating': 4.5,
#    'reference': 'ChIJQ4VJg3Hf3IARUwlv2UsFPvI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 235,
#    'vicinity': '4517 Campus Dr, Irvine'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.6570556, 'lng': -117.9083472},
#     'viewport': {'northeast': {'lat': 33.65834842989272,
#       'lng': -117.9068941701073},
#      'southwest': {'lat': 33.65564877010728, 'lng': -117.9095938298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "Hector's Tacos Y Mariscos",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108665003631734881340">M Fox</a>'],
#      'photo_reference': 'CmRaAAAAYBDJx5XCVkXHoay2w_erMGpS28AqjC8FxvB7p5f3iYTJq1JzliMLlgX6Ez7lqijqLxySVO3YacibXXZbxWJ3zmM_UBiYrm6O4lHqDbon1ptpW-9LLKJDFrPRRh_wN86WEhBcKfFkYpcNUGSPtqYp6lPwGhQONwg_u6V2mJvNlBebXhe3OGAQig',
#      'width': 3024}],
#    'place_id': 'ChIJ50Tz-p3f3IARzQNuEOPocpg',
#    'plus_code': {'compound_code': 'M34R+RM Costa Mesa, California, United States',
#     'global_code': '8554M34R+RM'},
#    'rating': 4.2,
#    'reference': 'ChIJ50Tz-p3f3IARzQNuEOPocpg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 89,
#    'vicinity': '2263 Fairview Rd UNIT G, Costa Mesa'}],
#  'status': 'OK'}

# %%
client.detail(place_id='ChIJRfptTwEg3YARACDUpVSiRso')
# Out:
# {'html_attributions': [],
#  'result': {'formatted_address': '407 31st St, Newport Beach, CA 92663, USA',
#   'formatted_phone_number': '(949) 673-9453',
#   'name': 'Wild Taco',
#   'rating': 4.4},
#  'status': 'OK'}

# %%
np.sort(a, axis=2)
