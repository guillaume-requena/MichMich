# %% [markdown]
# # Import and functions

# %%
import pandas as pd
import numpy as np
import requests
from urllib.parse import urlencode, urlparse , parse_qsl
import matplotlib.pyplot as plt

# %%
api_key = 'AIzaSyCEUIo5QkTQbHL8eBolEF6C4i0fSsnarFk'

# %%
def extract_lat_lng(address_or_postalcode, data_type = 'json'):
    '''
    extracts the lat and the lng from an adress
    '''
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {'address' : address_or_postalcode , "key" : api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200,299):
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except :
        pass
    return [latlng.get('lat'),latlng.get('lng')]

# %%
#Test 
#extract_lat_lng('24 boulevard du général Leclerc, Neuilly-sur-Seine, France')

# %%
def nearbysearch(lat, lng, radius, what = 'Bar'):
    '''
    returns the places corresponding to arg 'what' in a region of radius meters arround the point (lat,lng)
    '''
    places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params_2 = {
        "key" : api_key, 
        "location" : f"{lat},{lng}",
        "radius" : radius,
        "keyword" : what
    }
    params_2_encoded = urlencode(params_2)
    places_url = f"{places_endpoint_2}?{params_2_encoded}"
    r2 = requests.get(places_url)
    return r2.json()

# %%
#Test 
#nearbysearch(48.8890408,2.2596179,100)

# %%
def centre_gravite(points,coef_sum=[]):
    '''
    returns the centre de gravite of the points 
    '''
    points = np.array(points)
    if len(coef_sum)==0:
        coef_sum=np.array([1/len(points)]*len(points))
    x = np.array(points[:,0]*coef_sum).sum()
    y = np.array(points[:,1]*coef_sum).sum()
    return [x,y]

# %%
# #Test 

# points = [[2,3],[3,5],[0,6]]
# centre_gravite(points)

# %%
def get_time_and_distance_between_two_points(pt1,pt2,mode='transit'):
    '''
    returns the time in seconds between pt1 and pt2 according to the transport mode 'mode'
    mode can be : 
                    - driving 
                    - walking 
                    - bicycling 
                    - transit 
    '''
    lat1, lng1 = pt1[0],pt1[1]
    lat2, lng2 = pt2[0],pt2[1]
    detail_base_endpoint = 'https://maps.googleapis.com/maps/api/directions/json'
    detail_params = {
        "origin": str(lat1)+','+str(lng1),
        "destination" : str(lat2)+','+str(lng2),
        "key": api_key,
        "transit_mode" : "rail",
        "mode":mode
    }
    detail_params_encoded = urlencode(detail_params)
    detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"
    r = requests.get(detail_url)
    rep = r.json()
    duration = rep['routes'][0]['legs'][0]['duration']['value']
    distance = rep['routes'][0]['legs'][0]['distance']['value']
    return duration,distance

# %%
def normalize(vect):
    vect = np.array(vect)
    return vect/vect.sum()

# %%
# def change_center(old_center,points,weights):
#     weights = np.array(weights)
#     weights[(weights!=weights.max())&(weights!=weights.min())]=0
#     weights = normalize(weights)
    
#     x_new_center = old_center[0]+((points[:,0]-old_center[0])*weights).sum()
#     y_new_center = old_center[1]+((points[:,1]-old_center[1])*weights).sum()
#     return [x_new_center,y_new_center]

# %%
def main():
    n = int(input("Vous etes combien ? "))
    activity = input("Où voulez vous vous retrouvez? ")
    print("Moyen de transport disponibles: 'transit', 'walking', 'driving', 'cycling'")
    adresses = []
    transports = []
    for i in range(1,n+1):
        adresses.append(input(f"Entrez l'adresse n°{str(i)} : "))
        transports.append(input(f"Entrez votre moyen de transport n°{str(i)} : "))
    print('')
    print('**************************')
    print("Chargement des résultats")
    print('**************************')
    return mich_mich(adresses, modes_transport=transports, what = activity)

# %% [markdown]
# 24 boulevard du général Leclerc, Neuilly
#
# Place Monge, Paris
#
# Cité universitaire, Paris
#
# 19 Avenue Auguste Renoir, Marly-le-roi

# %%
r = main()
# Out:
# Vous etes combien ? 2
# Où voulez vous vous retrouvez? Piscine
# Moyen de transport disponibles: 'transit', 'walking', 'driving', 'cycling'
# Entrez l'adresse n°1 : Place Monge, Paris
# Entrez votre moyen de transport n°1 : transit
# Entrez l'adresse n°2 : 24 boulevard du général Leclerc, Neuilly
# Entrez votre moyen de transport n°2 : transit
#
# **************************
# Chargement des résultats
# **************************
# [1954 1506]
# [['Pool Jacqueline Auriol' '7 Allée Louis de Funès, Paris' '3.8' '496']
#  ['Piscine Emile Anthoine' '9 Rue Jean Rey, Paris' '3.6' '88']
#  ['Piscines de France' '10 Rue du Colisée, Paris' '2.8' '4']
#  ['IVORY POOL' '59 Rue de Ponthieu Bureau 562, Paris' '1' '2']
#  ['Henocque Piscines' '11 Rue Marbeuf, Paris' '0' '0']
#  ['Aqua Global Consulting' '66 Av. des Champs-Élysées, Paris' '0' '0']
#  ['La Piscine' '35 Avenue de la Grande Armée, Paris' '0' '0']]

# %%
r
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcnaJv0RCyKTBeLykckmieTGkjE4zOKasNMs4T2C8y9hq1coQyaXoNOTEw_Ie84Yr7QjiJ7RsSBCkLQaBrf8OXLzAkxyfIA7vxyRJU8MyyTVpwXwYt-QLx8ViPysy5bdHCD31blnEJE7QSHjC5u9ezKixYzdoBLxl-DABFJPHlZljGAzxcO012gFwPXJyRTbW1P2Pqw3mFAqpLmSlqz_BzpZghsj6PSv9dSruLuqO3qgotOkMTzmSKf37HCdPTwYzohpsW-FKfwpScqcQ5sXoEe4UUHk-zuQHFkFFWJWEK84s_u0ToEOXpoVuVnaaf2HmgUEm9ZxBv5K4QGyI3OMINCR45LH33-J4tmSVAVtPyi3wIWFLeGZWtWUvVTvc0Bjefob9aK1-_XYeEIWNoQK-g8jMuvrJHZ-xmpGyfgZZJ3XLpi_Lg',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8549938, 'lng': 2.305011},
#     'viewport': {'northeast': {'lat': 48.85637457989272,
#       'lng': 2.306512929892722},
#      'southwest': {'lat': 48.85367492010727, 'lng': 2.303813270107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Gatsby',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111400552418374088098">Gatsby</a>'],
#      'photo_reference': 'CmRaAAAAkcOeWh5XqhQbEzgwc6oECaIPq9efGAR5XfRJN4PSfaTWKQPKRePrTs8ZeVhkgScOFWJNn8sQD35vqo6fnW2ZwJDifP8U9wQcLasmYH8yvifrZa-xiOP2W2twOo3mw4O8EhDAGSHLJOduuTmHkIY6SlBDGhTb68nr2S_CZ-Yvg6MlsEfbr6W1Vw',
#      'width': 3264}],
#    'place_id': 'ChIJz6QnLSdw5kcRYbXZEC0xOuo',
#    'plus_code': {'compound_code': 'V834+X2 Paris',
#     'global_code': '8FW4V834+X2'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJz6QnLSdw5kcRYbXZEC0xOuo',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 280,
#    'vicinity': '64 Avenue Bosquet, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.851352, 'lng': 2.327127},
#     'viewport': {'northeast': {'lat': 48.85269072989271,
#       'lng': 2.328394979892722},
#      'southwest': {'lat': 48.84999107010727, 'lng': 2.325695320107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Joséphine',
#    'permanently_closed': True,
#    'photos': [{'height': 2736,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102468050443051800427">Denis CHEVALERAUD</a>'],
#      'photo_reference': 'CmRaAAAAwLQONUrW4rCrG3UgpCQahaJlQ5kdFzdA4CYDw-cpw0hbCOvrG9JsKGNYQDaGuS5ZzV6pKQHKTyy0-k8Wt3nlDdQBKDYRS0s5XopizaWIbVpHSs9znjno_H9NIRq_SHn3EhALwr6jDMiZ8LzaBmPrQDKdGhSsAUvh9l1WTFCoH2w8jgI02n-92w',
#      'width': 3648}],
#    'place_id': 'ChIJeZFhedFx5kcRCqB644LP9pU',
#    'plus_code': {'compound_code': 'V82G+GV Paris',
#     'global_code': '8FW4V82G+GV'},
#    'rating': 4.3,
#    'reference': 'ChIJeZFhedFx5kcRCqB644LP9pU',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 265,
#    'vicinity': '45 Boulevard Raspail, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85659279999999, 'lng': 2.3173764},
#     'viewport': {'northeast': {'lat': 48.85795592989273,
#       'lng': 2.318635979892723},
#      'southwest': {'lat': 48.85525627010728, 'lng': 2.315936320107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Home Bar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110675864583894495318">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA7g9kwheaSjmFlAvWk2T3Zj0ulxHUGm1wyTObAn-zT3sUup3v0rJT7fiXt-V8kNvGZ6ce7MrOkfQep5a7Uos0rRTjKZLvBpHiN19khNbj83mvUtBZhprWiXeGb7XM9uPnEhC1TTE17D9Xf4Q4M_FGHPHEGhQx-qZlgOFmC60o9-MjVuEFlo6e2Q',
#      'width': 4032}],
#    'place_id': 'ChIJkY1zCSpw5kcRIB6tHZsxJpk',
#    'plus_code': {'compound_code': 'V848+JX Paris',
#     'global_code': '8FW4V848+JX'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJkY1zCSpw5kcRIB6tHZsxJpk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'bar',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 122,
#    'vicinity': '47 Rue de Bourgogne, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8570566, 'lng': 2.3060999},
#     'viewport': {'northeast': {'lat': 48.85842737989272,
#       'lng': 2.307538629892723},
#      'southwest': {'lat': 48.85572772010728, 'lng': 2.304838970107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': "L'Éclair",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115612961127035131774">Richard</a>'],
#      'photo_reference': 'CmRaAAAAO8_MNJcKwm_w8zb5u5kw4ka1lsu-0PnzOwZK5uXTcd4ynpUx-GKNVEjfvHhJCsJzdHYfmDF1DSDoihuTHMknBIFkbh7QZRFIHgbNiYVjPnX8ZZjHHBD0zCkYVC3MVT6aEhCjnHuKyVFMMUQIpiarrXnAGhRnfPuERACUqH9RebBUEWMlTu6hfQ',
#      'width': 2048}],
#    'place_id': 'ChIJFczQXidw5kcRcmltFO7GGe8',
#    'plus_code': {'compound_code': 'V844+RC Paris',
#     'global_code': '8FW4V844+RC'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJFczQXidw5kcRcmltFO7GGe8',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 487,
#    'vicinity': '32 Rue Cler, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8428152, 'lng': 2.3260801},
#     'viewport': {'northeast': {'lat': 48.84415542989273,
#       'lng': 2.327456429892722},
#      'southwest': {'lat': 48.84145577010728, 'lng': 2.324756770107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Falstaff',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104222945105683318846">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAKbfy58dpHu5eWDOCM4jXu-ZQ0-UMiI84MonKUv5r5w4h5Xeu9uhvlltCS4-ZJ11MAoLK5cUaMDZiCfItAynI60wMHds3FWW2eK0TFtG-tY4jirz4CLtlVBb0vs8WQH1HEhBRM1QG0pDQGYq6TXA88V4lGhRXimvDubT59un__IMWhZwfCJIPWA',
#      'width': 3024}],
#    'place_id': 'ChIJOzl9Icxx5kcRWcga16oXZEw',
#    'plus_code': {'compound_code': 'R8VG+4C Paris',
#     'global_code': '8FW4R8VG+4C'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJOzl9Icxx5kcRWcga16oXZEw',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1971,
#    'vicinity': '42 Rue du Montparnasse, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85504659999999, 'lng': 2.304583},
#     'viewport': {'northeast': {'lat': 48.85633102989271,
#       'lng': 2.305838229892723},
#      'southwest': {'lat': 48.85363137010727, 'lng': 2.303138570107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Gloster',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1067,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110113817110735619960">Le Gloster</a>'],
#      'photo_reference': 'CmRaAAAA164a10DKnckdACZqyYmR1wK65J3OI4HGWFdLLEsURfvnUwG-7HcLyF9its5rO6xSlw3eQPi6wH9o489WWsjlBFiysVBnCSuynLrzyYHYqZ7W2eTtSIqkbDXTrHDDtxnPEhA_d_ANq22P7IQiKfqf8HiSGhQizQQxlI2VN5om2DNoieTrGBPyAA',
#      'width': 1600}],
#    'place_id': 'ChIJcx_R0yBw5kcRT-1rpSF1hZw',
#    'plus_code': {'compound_code': 'V843+2R Paris',
#     'global_code': '8FW4V843+2R'},
#    'rating': 4.5,
#    'reference': 'ChIJcx_R0yBw5kcRT-1rpSF1hZw',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 73,
#    'vicinity': '111 Avenue de la Bourdonnais, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.85667, 'lng': 2.32791},
#     'viewport': {'northeast': {'lat': 48.85808967989272,
#       'lng': 2.329226479892722},
#      'southwest': {'lat': 48.85539002010728, 'lng': 2.326526820107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Bar Signature',
#    'permanently_closed': True,
#    'photos': [{'height': 1332,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104767489622528261604">A Google User</a>'],
#      'photo_reference': 'CmRaAAAACgRrg1C-kox67iEo8AlSwLDCwP3PXp5wWRVMrHS7IiK2UxhvRlcMsWC3zMcIw9TmJvGesvE-MKW0dZsrge89ddDTSMtOgUE64fcIm9khj5XqKeqR3JUwcmPcEa9gsQlfEhBfTcUUSVLvWjVWgZPa74w_GhT1Dfew52gwVejXWe65Zz5X8-0hnA',
#      'width': 2000}],
#    'place_id': 'ChIJTVFo_ilu5kcRFr737ZbsncM',
#    'plus_code': {'compound_code': 'V84H+M5 Paris',
#     'global_code': '8FW4V84H+M5'},
#    'rating': 5,
#    'reference': 'ChIJTVFo_ilu5kcRFr737ZbsncM',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'bar', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '5-7 Rue de Montalembert, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8576563, 'lng': 2.3056077},
#     'viewport': {'northeast': {'lat': 48.85897852989272,
#       'lng': 2.306978679892722},
#      'southwest': {'lat': 48.85627887010728, 'lng': 2.304279020107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': "The World's Bar",
#    'place_id': 'ChIJe1b-sdhv5kcRKy2H1GsJptk',
#    'plus_code': {'compound_code': 'V854+36 Paris',
#     'global_code': '8FW4V854+36'},
#    'rating': 0,
#    'reference': 'ChIJe1b-sdhv5kcRKy2H1GsJptk',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '188 Rue de Grenelle, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8543296, 'lng': 2.3043103},
#     'viewport': {'northeast': {'lat': 48.85563407989272,
#       'lng': 2.305600629892722},
#      'southwest': {'lat': 48.85293442010727, 'lng': 2.302900970107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': "Dim's Bar",
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJS4WSGbpx5kcRn2CNsDXnkac',
#    'plus_code': {'compound_code': 'V833+PP Paris',
#     'global_code': '8FW4V833+PP'},
#    'rating': 5,
#    'reference': 'ChIJS4WSGbpx5kcRn2CNsDXnkac',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '9 Avenue Frédéric le Play, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84246170000001, 'lng': 2.3257796},
#     'viewport': {'northeast': {'lat': 48.84380062989272,
#       'lng': 2.327159429892722},
#      'southwest': {'lat': 48.84110097010728, 'lng': 2.324459770107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le 48',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115612391376929186486">lebron54</a>'],
#      'photo_reference': 'CmRaAAAANqGldDQK-q9u4w6pZybytyhUc3DlcMhB2OzWLAHt9nko1XbDlhiBsber8HoJJeI-upFEEoDb5srOJZlP_x5v3Ds1jDDcJXHY4yiOuTeQobO-LSBfcCdUQvrws7ALYER6EhDrcwpKfNBoNfNs_sSmmuoyGhQlqT1UOVSlLu9v378jwCyojYZ1Xg',
#      'width': 4032}],
#    'place_id': 'ChIJx_H9Gcxx5kcRfOglDMCznUQ',
#    'plus_code': {'compound_code': 'R8RG+X8 Paris',
#     'global_code': '8FW4R8RG+X8'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJx_H9Gcxx5kcRfOglDMCznUQ',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 383,
#    'vicinity': '48 Rue du Montparnasse, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.859475, 'lng': 2.3067302},
#     'viewport': {'northeast': {'lat': 48.86086562989271,
#       'lng': 2.308061879892723},
#      'southwest': {'lat': 48.85816597010727, 'lng': 2.305362220107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Bar du Central',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106164510152723353528">Charles Reid</a>'],
#      'photo_reference': 'CmRaAAAAYrBZl8jB2jZBtXQQhJXWUL0YqArIQ1QzfBA7m-POCYLragukx5kYDtPB9ouJufGDFZqelb1pZs4L0E7VRuhM8gcT5Yt6RuKfQfoJFJqpPjinscvPYNR84MGpha2wvVguEhBJbKNPfKsT-Dxlg-iKx9akGhTBAL-FdSNp9w23xMSYOIehRV-xQw',
#      'width': 4128}],
#    'place_id': 'ChIJX1hmctdv5kcRg9cTYs5iwHA',
#    'plus_code': {'compound_code': 'V854+QM Paris',
#     'global_code': '8FW4V854+QM'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJX1hmctdv5kcRg9cTYs5iwHA',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 312,
#    'vicinity': '99 Rue Saint-Dominique, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8512444, 'lng': 2.3272378},
#     'viewport': {'northeast': {'lat': 48.85257812989272,
#       'lng': 2.328468829892722},
#      'southwest': {'lat': 48.84987847010728, 'lng': 2.325769170107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Bar Aristide',
#    'permanently_closed': True,
#    'photos': [{'height': 2145,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116039042478349650841">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAQTJAwlqYPZMwoNzSZw5dmPGGMxt0ig_85vgiMac0EeCjvCOg90a_s2yA9HMirCc3V8U5KFR3wFVbEyTkKyJTTzvKs2M1OTe10d7W8QLdjHGe8xFGZpFMeHk_-HyOYIyqEhCcO59vzQYNhflAQ1shO6QJGhQHh5tsU2knerhzUt6ndQSG1rnaOA',
#      'width': 4000}],
#    'place_id': 'ChIJEyZFVcZx5kcRnh9eUvB41XE',
#    'plus_code': {'compound_code': 'V82G+FV Paris',
#     'global_code': '8FW4V82G+FV'},
#    'rating': 0,
#    'reference': 'ChIJEyZFVcZx5kcRnh9eUvB41XE',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '45 Boulevard Raspail, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84578339999999, 'lng': 2.3099211},
#     'viewport': {'northeast': {'lat': 48.84709662989273,
#       'lng': 2.311160729892722},
#      'southwest': {'lat': 48.84439697010728, 'lng': 2.308461070107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'name': 'Le Cristal',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106155161110817415714">Alexandre de Belleroche</a>'],
#      'photo_reference': 'CmRaAAAANXW2P_1iwSGrjb1zBmoPjxA9qyOt7G7lJU9KpLzzZuWe_zGyZcKux-sF_8BVEoj6buyFFakJjQb6752SlfW1IjHseiE-XzApVoo5d_8n4CDYn1AlYZzf-_1bLK_7EldQEhCsuwZXmo3ZdFjFjIB4Ux99GhSWB6Sv8Zg8CRTHDv4mk9ovkJWB8Q',
#      'width': 4640}],
#    'place_id': 'ChIJSxd9CjBw5kcR7ww2raHxnME',
#    'plus_code': {'compound_code': 'R8W5+8X Paris',
#     'global_code': '8FW4R8W5+8X'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJSxd9CjBw5kcR7ww2raHxnME',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 791,
#    'vicinity': '163 Avenue de Suffren, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85859199999999, 'lng': 2.3098591},
#     'viewport': {'northeast': {'lat': 48.85993752989271,
#       'lng': 2.311306079892722},
#      'southwest': {'lat': 48.85723787010727, 'lng': 2.308606420107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Fitzgerald',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1193,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109696684269947346460">A Google User</a>'],
#      'photo_reference': 'CmRaAAAASkCEAcQoGidW17fUbjDamtMU8lRxqg5Kcw-hyX7nDSO4QIF_AYjM42HYrhoPZETnQO8jYdLzJsdX2worMupuPBk0V2c8rP91WD1n2x9CfhM14x8gDCRDE0_juyknFa9gEhDKmhsXUw3Ne4kq9vu7vuP9GhRLHhfUX4ZbZJWbcVMfgz_TLrBVSQ',
#      'width': 1590}],
#    'place_id': 'ChIJsU2oOdhv5kcRfOa5j5inq5Q',
#    'plus_code': {'compound_code': 'V855+CW Paris',
#     'global_code': '8FW4V855+CW'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJsU2oOdhv5kcRfOa5j5inq5Q',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 358,
#    'vicinity': '54 Boulevard de la Tour-Maubourg, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8595524, 'lng': 2.3063737},
#     'viewport': {'northeast': {'lat': 48.86087962989272,
#       'lng': 2.307733579892722},
#      'southwest': {'lat': 48.85817997010728, 'lng': 2.305033920107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'LE MALABAR - PARIS',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113445792700474482252">David Oliphant</a>'],
#      'photo_reference': 'CmRaAAAA0seoobR3mqWB0R2CErSUQJrEjALl7V4gC9Xxpn05aPw3RGCOz0aJRBNYpacJbOE1zXEiyQ6EB1m1JyULpKXH-rG3idddCYyJB1hFZ_cIOe1nnleAZ3Syk6dRcqanRT6CEhBH796XYflcWXr-rBfrCd-yGhTco1sbtPAY1vebTmYrNlL-JiB4Zw',
#      'width': 4032}],
#    'place_id': 'ChIJv6UBKNlv5kcR3oIrH7Kp1cI',
#    'plus_code': {'compound_code': 'V854+RG Paris',
#     'global_code': '8FW4V854+RG'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJv6UBKNlv5kcR3oIrH7Kp1cI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'cafe',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 387,
#    'vicinity': '88 Rue Saint-Dominique, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8487769, 'lng': 2.3253408},
#     'viewport': {'northeast': {'lat': 48.85017937989272,
#       'lng': 2.326623429892722},
#      'southwest': {'lat': 48.84747972010727, 'lng': 2.323923770107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Le Nemrod',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2848,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115793564094981467251">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAlZOUXBqphiZTQ1y6lthbUfS3KMQJM5X0PiMEvO6PIQhpmtTH5PSFfV5uDqBp2yduNts1Vcnz3fMnOzH7jR3zHGj2g_j3RQmOruGS8iibIKLzpf8YDuHXhVcGlWfiWnqZEhBh0t2lNgrVo-5ycQ1nRu2LGhT6YnbEZ51Vo7KZISP4n7CLNyROAA',
#      'width': 4288}],
#    'place_id': 'ChIJEzmlS9Jx5kcRiRH64ELcKws',
#    'plus_code': {'compound_code': 'R8XG+G4 Paris',
#     'global_code': '8FW4R8XG+G4'},
#    'rating': 3.9,
#    'reference': 'ChIJEzmlS9Jx5kcRiRH64ELcKws',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 419,
#    'vicinity': '51 Rue du Cherche-Midi, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8507842, 'lng': 2.3306378},
#     'viewport': {'northeast': {'lat': 48.85217172989272,
#       'lng': 2.331891079892722},
#      'southwest': {'lat': 48.84947207010728, 'lng': 2.329191420107278}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'name': 'Café Cassette',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 737,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107098671152168846578">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAPTCdaqvDmZgNpheWlyHc-AtfdxMzWgXlHvNxjbbZ0G8vf4CzfDi2LHV-jMkLbHcf2HnxSdddVo8FqCOL38KbQSQ8WGquo_L11_j0rl8BBiqMsAEMO-S2zz9Vv16aetmUEhDgHc9x_-zl96or9gxUTE6CGhTRMifC65vVvWK9fyHlPXYC6O-l6w',
#      'width': 750}],
#    'place_id': 'ChIJc6_g0dBx5kcR38Wrm3QP7tA',
#    'plus_code': {'compound_code': 'V82J+87 Paris',
#     'global_code': '8FW4V82J+87'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJc6_g0dBx5kcR38Wrm3QP7tA',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 911,
#    'vicinity': '73 Rue de Rennes, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84269399999999, 'lng': 2.3281246},
#     'viewport': {'northeast': {'lat': 48.84399227989272,
#       'lng': 2.329436079892722},
#      'southwest': {'lat': 48.84129262010728, 'lng': 2.326736420107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': "L'ATELIER - PARIS",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114315763380453729003">Jean Vincent</a>'],
#      'photo_reference': 'CmRaAAAARuIxqKO6Ww9Z0nskol5UUEB1_utde8fADdU2SX5tjnDA2E6sBmXA-Ij9gnima9pTI823Cpf3LOrlHU0ZiCEgb5FWVy_hyIbL_LGo3mjkc_HRY0qe7qVMmnNntNuBQhAcEhCr2SAdeDpTuehoIzpLIOs4GhQZk6lQfLus-yIjPGSnuXovoAP2dQ',
#      'width': 4032}],
#    'place_id': 'ChIJMXme6s5x5kcRenNgzCohxGI',
#    'plus_code': {'compound_code': 'R8VH+36 Paris',
#     'global_code': '8FW4R8VH+36'},
#    'price_level': 2,
#    'rating': 3.4,
#    'reference': 'ChIJMXme6s5x5kcRenNgzCohxGI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'cafe',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 444,
#    'vicinity': '95 Boulevard du Montparnasse, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8494219, 'lng': 2.3259675},
#     'viewport': {'northeast': {'lat': 48.85073452989272,
#       'lng': 2.327364429892722},
#      'southwest': {'lat': 48.84803487010727, 'lng': 2.324664770107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Le Phylo',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115641600541833615880">Le Phylo</a>'],
#      'photo_reference': 'CmRaAAAAmR5A-feJ1BIMzjFrZnSB3JiD0QyjrjVwrrdNiOdPDQUhPw-edR2bpucyPyGwb1DfVFRr8yjEwiCr3dyXH90ckaAKinx7GQa6Ktaj5xej5jVGpJXWbnbQiQft477tdbVjEhDBO-lUbTQOUBVPb2sFwq0bGhTshFbKTa4NwGuXmC0TE-8AmWWMEg',
#      'width': 960}],
#    'place_id': 'ChIJiSwnzNNx5kcRaFI1Ggim4zM',
#    'plus_code': {'compound_code': 'R8XG+Q9 Paris',
#     'global_code': '8FW4R8XG+Q9'},
#    'rating': 0,
#    'reference': 'ChIJiSwnzNNx5kcRaFI1Ggim4zM',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '48 Rue du Cherche-Midi, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8431377, 'lng': 2.3138279},
#     'viewport': {'northeast': {'lat': 48.84455582989272,
#       'lng': 2.315128479892722},
#      'southwest': {'lat': 48.84185617010727, 'lng': 2.312428820107277}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Le Necker Bar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3968,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107338152198215417274">C D.</a>'],
#      'photo_reference': 'CmRaAAAAJq28v6oiLfyEhoogawOa9i9H87MgxWEVdvFlXaysYxwKEvBItZQB4LAacak9HCy-UpF5g3bc0l85en7xJ86moXM668Gsh7cLOEz3kmReFIAwxLQp6Q66f_HNB7LoOjfDEhBqDzGMhYnnH4PIvG_ARy91GhSkfJkmCoqKKORvQlJhQ8ivQ19Z1Q',
#      'width': 2976}],
#    'place_id': 'ChIJAQAkFTFw5kcR4AssDlEXBP4',
#    'plus_code': {'compound_code': 'R8V7+7G Paris',
#     'global_code': '8FW4R8V7+7G'},
#    'rating': 3.8,
#    'reference': 'ChIJAQAkFTFw5kcR4AssDlEXBP4',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': '175 Rue de Vaugirard, Paris'}],
#  'status': 'OK'}

# %%
def mich_mich(adresses, modes_transport, what = 'Bar',radius=1000):
    '''
    main function
    '''
    n = len(adresses)
    #Get the point in the middle 
    points = np.array([extract_lat_lng(adr) for adr in adresses])
    lat , lng = centre_gravite(points)
    center = [lat,lng]
    
    #Verifying that the new point is at an equal distance of everyone
    #If it's not the case, recalculates a new point 
    durations = []
    distances = []
    for i in range(n):
        p = points[i]
        transport_p = modes_transport[i]
        duration_p, distance_p = get_time_and_distance_between_two_points(p,center,transport_p)
        durations.append(duration_p)
        distances.append(distance_p)
    durations, distances = np.array(durations), np.array(distances)
    min_duration = durations.min()
    max_duration = durations.max()
    print(durations)
  
    #Get the results of the places at a distance < radius of the center calculated
    results =  nearbysearch(lat, lng, radius, what)
    n = len(results['results'])
    res = [ [results['results'][i]['name'],results['results'][i]['vicinity'], results['results'][i]['rating'] , results['results'][i]['user_ratings_total']]  for i in range(n)]
    res = np.array(res)
    res = np.flip(res[(res[:,2]).argsort()] , axis =0)
    print(res)
    return res

# %%
(np.array([0.34801871, 0.43637706, 0.21560423])*np.array([2.3521469,2.3089514,2.3385613])).sum()
# Out:
# 2.330368261877682

# %%
mich_mich(adresses, transports, what = 'Bar')
# Out:
# [[48.8427046  2.3521469]
#  [48.8278931  2.3089514]
#  [48.8198027  2.3385613]]
# coef_sum [0.33333333 0.33333333 0.33333333]
# points [[48.8427046  2.3521469]
#  [48.8278931  2.3089514]
#  [48.8198027  2.3385613]]
# [1354 1773  876]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.33824632 0.44291781 0.21883587]
# [48.825217678935445, 2.318743122310306]
# nouvelles durées [1708  757  392]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.59782989 0.26496325 0.13720686]
# [48.83842957866666, 2.3496109213333334]
# nouvelles durées [ 423 2913 1747]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.08321857 0.57308676 0.34369467]
# [48.829771176888485, 2.3144285272482015]
# nouvelles durées [1825  602  847]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.55742211 0.18387294 0.25870495]
# [48.83903071330861, 2.3414325650185415]
# nouvelles durées [ 945 2597  953]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.21023359 0.57775306 0.21201335]
# [48.831844784782604, 2.3204758911067196]
# nouvelles durées [1739  952 1061]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.46348614 0.25373134 0.28278252]
# [48.83746470850984, 2.3368655488294316]
# nouvelles durées [1284 2538  897]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.27209154 0.53782581 0.19008264]
# [48.82578041039301, 2.3166835922270743]
# nouvelles durées [1841  633  525]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.61387129 0.21107036 0.17505835]
# [48.83762281745562, 2.3491323437869824]
# nouvelles durées [ 473 2841 1755]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.09331229 0.56046558 0.34622213]
# [48.83000711312613, 2.315116599607725]
# nouvelles durées [1798  647  891]
# ce n'est pas juste, je recommence
# nouvelle durées pour calcul [0.53896882 0.19394484 0.26708633]
# [48.83878515603272, 2.340716434355828]
# nouvelles durées [ 956 2503  859]
# 3926
# 100
# [['Café Léa' '5 Rue Claude Bernard, Paris' '4.4' '491']
#  ['Aux Marsouins' '50 Boulevard de Port-Royal, Paris' '4.6' '188']
#  ['Bar Le 1802' '22 Rue Pascal, Paris' '4.7' '73']
#  ['La belle mine' '58 Rue Claude Bernard, Paris' '4.7' '112']
#  ['Le Repaire' '20 Rue Censier, Paris' '4.1' '154']
#  ['Bar Tabac' '123 Rue Monge, Paris' '4.5' '8']
#  ['Bar On Fleek Mouffetard' '104 Rue Mouffetard, Paris' '4.6' '18']
#  ['Fischer Winner Bar' '4 Rue Michel Peter, Paris' '4.8' '5']
#  ['Bar À Bières Cocktails' 'Rue de la Glacière, Paris' '0' '0']]
# array([['Fischer Winner Bar', '4 Rue Michel Peter, Paris', '4.8', '5'],
#        ['La belle mine', '58 Rue Claude Bernard, Paris', '4.7', '112'],
#        ['Bar Le 1802', '22 Rue Pascal, Paris', '4.7', '73'],
#        ['Bar On Fleek Mouffetard', '104 Rue Mouffetard, Paris', '4.6',
#         '18'],
#        ['Aux Marsouins', '50 Boulevard de Port-Royal, Paris', '4.6',
#         '188'],
#        ['Bar Tabac', '123 Rue Monge, Paris', '4.5', '8'],
#        ['Café Léa', '5 Rue Claude Bernard, Paris', '4.4', '491'],
#        ['Le Repaire', '20 Rue Censier, Paris', '4.1', '154'],
#        ['Bar À Bières Cocktails', 'Rue de la Glacière, Paris', '0', '0']],
#       dtype='<U33')

# %% [markdown]
# 24 boulevard du général Leclerc, Neuilly
#
# Place Monge, Paris
#
# Cité universitaire, Paris
#
# 19 Avenue Auguste Renoir, Paris

# %%
n = int(input("Vous etes combien ? "))
where = input("Vous voulez aller où? ")
adresses = []
for i in range(n):
    adresses.append(input("Entrez l'adresse n°{} : ".format(str(i))))
# Out:
# Vous etes combien ? 3
# Vous voulez aller où? Bar
# Entrez l'adresse n°0 : Place Monge, Paris
# Entrez l'adresse n°1 : 19 Avenue Auguste Renoir, Paris
# Entrez l'adresse n°2 : Cité universitaire, Paris

# %%
adresses
# Out:
# ['Place Monge, Paris ',
#  '19 Avenue Auguste Renoir, Paris',
#  'Cité universitaire, Paris']

# %%
transports = ["transit","walking","transit"]

# %%
mich_mich(adresses, transports, what = 'Bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-88efb8917f38> in <module>
# ----> 1 mich_mich(adresses, transports, what = 'Bar')
#
# <ipython-input-35-8947efe01209> in mich_mich(adresses, modes_transport, what)
#      16         p = points[i]
#      17         transport_p = modes_transport[i]
# ---> 18         duration_p, distance_p = get_time_and_distance_between_two_points(p,center,transport_p)
#      19         durations.append(duration_p)
#      20         distances.append(distance_p)
#
# NameError: name 'get_time_and_distance_between_two_points' is not defined
