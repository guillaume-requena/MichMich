# %%
# Imports 

import pandas as pd
import numpy as np
import requests
from urllib.parse import urlencode, urlparse , parse_qsl
import matplotlib.pyplot as plt

# %%
# Create an environment variable 

api_key = 'AIzaSyCEUIo5QkTQbHL8eBolEF6C4i0fSsnarFk'

# %%
def extract_lat_lng(address_or_postalcode, data_type = 'json'):
    '''
    extracts the lat and the lng from an adress
    '''
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {'address' : address_or_postalcode , "key" : api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200,299):
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except :
        pass
    return [latlng.get('lat'),latlng.get('lng')]

# %%
def nearbysearch(lat, lng, radius, what = 'Bar'):
    '''
    returns the places corresponding to arg 'what' in a region of radius meters arround the point (lat,lng)
    '''
    places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params_2 = {
        "key" : api_key, 
        "location" : f"{lat},{lng}",
        "radius" : radius,
        "keyword" : what
    }
    params_2_encoded = urlencode(params_2)
    places_url = f"{places_endpoint_2}?{params_2_encoded}"
    r2 = requests.get(places_url)
    return r2.json()

# %%
def get_time_and_distance_between_two_points(pt1,pt2,mode='transit'):
    '''
    returns the time in seconds between pt1 and pt2 according to the transport mode 'mode'
    mode can be : 
                    - driving 
                    - walking 
                    - bicycling 
                    - transit 
    '''
    lat1, lng1 = pt1[0],pt1[1]
    lat2, lng2 = pt2[0],pt2[1]
    detail_base_endpoint = 'https://maps.googleapis.com/maps/api/directions/json'
    detail_params = {
        "origin": str(lat1)+','+str(lng1),
        "destination" : str(lat2)+','+str(lng2),
        "key": api_key,
        "transit_mode" : "rail",
        "mode":mode
    }
    detail_params_encoded = urlencode(detail_params)
    detail_url = f"{detail_base_endpoint}?{detail_params_encoded}"
    r = requests.get(detail_url)
    rep = r.json()
    duration = rep['routes'][0]['legs'][0]['duration']['value']
    distance = rep['routes'][0]['legs'][0]['distance']['value']
    return duration,distance

# %%
def centre_gravite(points,coef_sum=[]):
    '''
    returns the centre de gravite of the points 
    '''
    points = np.array(points)
    if len(coef_sum)==0:
        coef_sum=np.array([1/len(points)]*len(points))
    x = np.array(points[:,0]*coef_sum).sum()
    y = np.array(points[:,1]*coef_sum).sum()
    return [x,y]

def normalize(vect):
    vect = np.array(vect)
    return vect/vect.sum()

# %%
# Mich mich function 

def mich_mich(adresses, modes_transport, what = 'Bar',radius=1000):
    '''
    main function
    '''
    n = len(adresses)
    #Get the point in the middle 
    points = np.array([extract_lat_lng(adr) for adr in adresses])
    lat , lng = centre_gravite(points)
    center = [lat,lng]
    
    #Verifying that the new point is at an equal distance of everyone
    #If it's not the case, recalculates a new point 
    durations = []
    distances = []
    for i in range(n):
        p = points[i]
        transport_p = modes_transport[i]
        duration_p, distance_p = get_time_and_distance_between_two_points(p,center,transport_p)
        durations.append(duration_p)
        distances.append(distance_p)
    durations, distances = np.array(durations), np.array(distances)
    min_duration = durations.min()
    max_duration = durations.max()
    print(durations)
  
    #Get the results of the places at a distance < radius of the center calculated
    results =  nearbysearch(lat, lng, radius, what)
    df_results = pd.DataFrame(results['results'])
    return df_results

# %% [markdown]
# 24 boulevard du général Leclerc, Neuilly
#
# Place Monge, Paris
#
# Cité universitaire, Paris
#
# 19 Avenue Auguste Renoir, Marly-le-roi

# %%
def main():
    n = int(input("Vous etes combien ? "))
    activity = input("Où voulez vous vous retrouvez? ")
    print("Moyen de transport disponibles: 'transit', 'walking', 'driving', 'cycling'")
    adresses = []
    transports = []
    for i in range(1,n+1):
        adresses.append(input(f"Entrez l'adresse n°{str(i)} : "))
        transports.append(input(f"Entrez votre moyen de transport n°{str(i)} : "))
    print('')
    print('**************************')
    print("Chargement des résultats")
    print('**************************')
    return mich_mich(adresses, modes_transport=transports, what = activity)

# %%
r = main()
# Out:
# Vous etes combien ? 2
# Où voulez vous vous retrouvez? Bar
# Moyen de transport disponibles: 'transit', 'walking', 'driving', 'cycling'
# Entrez l'adresse n°1 : 19 Avenue Auguste Renoir, Marly-le-roi
# Entrez votre moyen de transport n°1 : transit
# Entrez l'adresse n°2 : Cité universitaire, Paris
# Entrez votre moyen de transport n°2 : transit
#
# **************************
# Chargement des résultats
# **************************
# [2288 3084]

# %%
def standard(x):
    x_std = (x-x.min())/(x.max()-x.min())
    x_scaled = x_std * (x.max() - x.min()) + x.min()
    return x_std

# %%
# Divers façon de ranking

# %%
r['note']=standard(r['rating'])*standard(r['user_ratings_total'])
r['note2']=r['price_level']+(r['note']/r['note'].max())

# %%
r.sort_values(by='note',ascending=False)
r.sort_values(by='note2')
# Out:
#        business_status                                           geometry  \
# 9          OPERATIONAL  {'location': {'lat': 48.8519847, 'lng': 2.2039...
# 8          OPERATIONAL  {'location': {'lat': 48.8522413, 'lng': 2.2214...
# 5          OPERATIONAL  {'location': {'lat': 48.85189219999999, 'lng':...
# 12         OPERATIONAL  {'location': {'lat': 48.8590358, 'lng': 2.2141...
# 10         OPERATIONAL  {'location': {'lat': 48.84326189999999, 'lng':...
# 7          OPERATIONAL  {'location': {'lat': 48.8403317, 'lng': 2.2284...
# 0   CLOSED_TEMPORARILY  {'location': {'lat': 48.8441841, 'lng': 2.2196...
# 6   CLOSED_TEMPORARILY  {'location': {'lat': 48.8520625, 'lng': 2.2234...
# 1          OPERATIONAL  {'location': {'lat': 48.84740859999999, 'lng':...
# 2          OPERATIONAL  {'location': {'lat': 48.8444088, 'lng': 2.2189...
# 3          OPERATIONAL  {'location': {'lat': 48.8428712, 'lng': 2.2129...
# 4          OPERATIONAL  {'location': {'lat': 48.8473429, 'lng': 2.2144...
# 11         OPERATIONAL  {'location': {'lat': 48.8421826, 'lng': 2.2074...
# 13         OPERATIONAL  {'location': {'lat': 48.8406075, 'lng': 2.2314...
# 14         OPERATIONAL  {'location': {'lat': 48.84235400000001, 'lng':...
#
#                                                  icon  \
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                 name permanently_closed  \
# 9                         P.M.U (Pari Mutuel Urbain)                NaN
# 8                                 Le Nouveau Village                NaN
# 5                                       Le Beau Site                NaN
# 12                                 Tabac du Val d'Or                NaN
# 10                                         Reef Club                NaN
# 7                                      Café des Arts                NaN
# 0                            Le Comptoir Saint-Cloud               True
# 6                                         Quai Ouest               True
# 1                                          P'tit Bar                NaN
# 2                                    Bar de la Poste                NaN
# 3                                              J S K                NaN
# 4                                    Les Fines Caves                NaN
# 11                                        Le Magenta                NaN
# 13  Tabac FDJ cigarette Électronique E-cig le Narval                NaN
# 14                           Picadeli, bar à salades                NaN
#
#                                                photos  \
# 9                                                 NaN
# 8   [{'height': 1080, 'html_attributions': ['<a hr...
# 5   [{'height': 2336, 'html_attributions': ['<a hr...
# 12  [{'height': 2592, 'html_attributions': ['<a hr...
# 10  [{'height': 1362, 'html_attributions': ['<a hr...
# 7   [{'height': 2448, 'html_attributions': ['<a hr...
# 0   [{'height': 3024, 'html_attributions': ['<a hr...
# 6   [{'height': 1600, 'html_attributions': ['<a hr...
# 1                                                 NaN
# 2   [{'height': 4032, 'html_attributions': ['<a hr...
# 3   [{'height': 4160, 'html_attributions': ['<a hr...
# 4   [{'height': 1776, 'html_attributions': ['<a hr...
# 11  [{'height': 2592, 'html_attributions': ['<a hr...
# 13  [{'height': 1701, 'html_attributions': ['<a hr...
# 14  [{'height': 1080, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 9   ChIJIWpKbEl75kcR7jepu23T4gM
# 8   ChIJ0e0bPS575kcRhJ_KX4coW-M
# 5   ChIJ4cta7zZ75kcRUshPoN1W3hU
# 12  ChIJK6pyNstk5kcRTfquvxYEaRU
# 10  ChIJh8UQ4SN75kcRc4TjLML3ZBw
# 7   ChIJAxg3UiB75kcRlEJWQgM-VnI
# 0   ChIJgeplTjt75kcRoNHYZfHZ2AQ
# 6   ChIJpbRVZy575kcRqto0igLSwOQ
# 1   ChIJN03Eijl75kcRA3qnkrvdPE0
# 2   ChIJdRtmQzt75kcR10WJ0JdFmds
# 3   ChIJOY0Vxz575kcRWa9gThhvwdk
# 4   ChIJUzqHizl75kcRymkPsM3hLjw
# 11  ChIJM-mN40B75kcRIpRSXFsgtUU
# 13  ChIJFZ48IUV75kcRtFZteQsHuOA
# 14  ChIJldielbd75kcRaWGjpwPf0H4
#
#                                             plus_code  price_level  rating  \
# 9   {'compound_code': 'V623+QH Saint-Cloud', 'glob...          1.0     4.3
# 8   {'compound_code': 'V62C+VH Saint-Cloud', 'glob...          1.0     4.0
# 5   {'compound_code': 'V627+Q6 Saint-Cloud', 'glob...          1.0     3.9
# 12  {'compound_code': 'V657+JJ Saint-Cloud', 'glob...          1.0     4.1
# 10  {'compound_code': 'R6VG+8M Boulogne-Billancour...          2.0     4.2
# 7   {'compound_code': 'R6RH+49 Boulogne-Billancour...          2.0     4.0
# 0   {'compound_code': 'R6V9+MR Saint-Cloud', 'glob...          2.0     4.0
# 6   {'compound_code': 'V62F+R9 Saint-Cloud', 'glob...          2.0     3.9
# 1   {'compound_code': 'R6W7+XQ Saint-Cloud', 'glob...          NaN     1.0
# 2   {'compound_code': 'R6V9+QH Saint-Cloud', 'glob...          NaN     3.3
# 3   {'compound_code': 'R6V7+45 Saint-Cloud', 'glob...          NaN     3.7
# 4   {'compound_code': 'R6W7+WQ Saint-Cloud', 'glob...          NaN     4.4
# 11  {'compound_code': 'R6R4+VX Saint-Cloud', 'glob...          NaN     3.4
# 13  {'compound_code': 'R6RJ+6H Boulogne-Billancour...          NaN     4.0
# 14  {'compound_code': 'R6RJ+W4 Boulogne-Billancour...          NaN     0.0
#
#                       reference   scope  \
# 9   ChIJIWpKbEl75kcR7jepu23T4gM  GOOGLE
# 8   ChIJ0e0bPS575kcRhJ_KX4coW-M  GOOGLE
# 5   ChIJ4cta7zZ75kcRUshPoN1W3hU  GOOGLE
# 12  ChIJK6pyNstk5kcRTfquvxYEaRU  GOOGLE
# 10  ChIJh8UQ4SN75kcRc4TjLML3ZBw  GOOGLE
# 7   ChIJAxg3UiB75kcRlEJWQgM-VnI  GOOGLE
# 0   ChIJgeplTjt75kcRoNHYZfHZ2AQ  GOOGLE
# 6   ChIJpbRVZy575kcRqto0igLSwOQ  GOOGLE
# 1   ChIJN03Eijl75kcRA3qnkrvdPE0  GOOGLE
# 2   ChIJdRtmQzt75kcR10WJ0JdFmds  GOOGLE
# 3   ChIJOY0Vxz575kcRWa9gThhvwdk  GOOGLE
# 4   ChIJUzqHizl75kcRymkPsM3hLjw  GOOGLE
# 11  ChIJM-mN40B75kcRIpRSXFsgtUU  GOOGLE
# 13  ChIJFZ48IUV75kcRtFZteQsHuOA  GOOGLE
# 14  ChIJldielbd75kcRaWGjpwPf0H4  GOOGLE
#
#                                                 types  user_ratings_total  \
# 9             [bar, point_of_interest, establishment]                   3
# 8   [restaurant, bar, food, point_of_interest, est...                  38
# 5             [bar, point_of_interest, establishment]                  96
# 12            [bar, point_of_interest, establishment]                  93
# 10  [restaurant, bar, food, point_of_interest, est...                 207
# 7   [restaurant, night_club, bar, food, point_of_i...                 390
# 0   [restaurant, bar, food, point_of_interest, est...                 820
# 6   [bar, restaurant, food, point_of_interest, est...                1556
# 1             [bar, point_of_interest, establishment]                   1
# 2             [bar, point_of_interest, establishment]                  16
# 3   [bar, restaurant, food, point_of_interest, est...                  29
# 4             [bar, point_of_interest, establishment]                  63
# 11  [restaurant, bar, food, point_of_interest, est...                 129
# 13            [bar, point_of_interest, establishment]                   6
# 14  [restaurant, food, point_of_interest, establis...                   0
#
#                                              vicinity        opening_hours  \
# 9                    171 Rue de Buzenval, Saint-Cloud                   {}
# 8               4 Avenue Bernard Palissy, Saint-Cloud  {'open_now': False}
# 5         140 Boulevard de la République, Saint-Cloud   {'open_now': True}
# 12            56-60 Rue du Mont Valérien, Saint-Cloud   {'open_now': True}
# 10  Face, 11 Quai du 4 Septembre, Boulogne-Billanc...  {'open_now': False}
# 7   7 Rond-Point Rhin et Danube, Boulogne-Billancourt   {'open_now': True}
# 0                   10 Place du Moustier, Saint-Cloud                  NaN
# 6              1200 Quai Marcel Dassault, Saint-Cloud                  NaN
# 1          98 Boulevard de la République, Saint-Cloud                  NaN
# 2          4 Place du Pas de Saint-Cloud, Saint-Cloud   {'open_now': True}
# 3                          11 Rue Gounod, Saint-Cloud   {'open_now': True}
# 4          96 Boulevard de la République, Saint-Cloud   {'open_now': True}
# 11                       1 Place Magenta, Saint-Cloud   {'open_now': True}
# 13        144 Route de la Reine, Boulogne-Billancourt   {'open_now': True}
# 14  Dans le Monop, 104 Avenue Jean Baptiste Clemen...  {'open_now': False}
#
#         note     note2
# 9   0.001884  1.002126
# 8   0.022201  1.025048
# 5   0.054686  1.061697
# 12  0.055694  1.062834
# 10  0.126986  2.143267
# 7   0.227857  2.257069
# 0   0.479084  2.540505
# 6   0.886364  3.000000
# 1   0.000146       NaN
# 2   0.007712       NaN
# 3   0.015672       NaN
# 4   0.040488       NaN
# 11  0.064063       NaN
# 13  0.003505       NaN
# 14  0.000000       NaN
